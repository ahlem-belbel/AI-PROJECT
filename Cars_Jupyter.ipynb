# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd

cars=[]
                                    #BMW
for i in range (1,10):
    url=f'https://www.otomoto.pl/osobowe/bmw?page=i'
    response=requests.get(url)
    response=response.content
    soup=BeautifulSoup(response,'html.parser')
    div=soup.find('div',class_="ooa-r53y0q ezh3mkl11")
    articles=div.find_all('article',class_='ooa-yca59n eszxync0')
    for article in articles:
                                               #name
        name=article.find('a').text
        print(name)
                                               #space
        space=article.find('p',class_='eszxync10 ooa-1tku07r er34gjf0').text
        space=space[:9]
        print(space)
                                               # kilometers
        km=article.find('p',class_='eszxync10 ooa-1tku07r er34gjf0').text
        km=km[13:18]
        print(km)
                                               #price
        price=article.find('h3',class_='eszxync16 ooa-1n2paoq er34gjf0').text
        price+=article.find('p',class_='eszxync17 ooa-8vn6i7 er34gjf0').text
        print(price)
      #                                          #kilometrage
        kilometrage=article.find('dd',class_='ooa-1omlbtp eszxync13').text
        print(kilometrage)
                                               #essence

        essence=article.find('dl', class_="ooa-1omlbtp eszxync13")
        essence=article.find(attrs={'data-parameter':"fuel_type"}).text.strip()
        print(essence)
                                               # gearbox_type==manuelle ou automatique

        gearbox_type=article.find('dl', class_="ooa-1omlbtp eszxync13")
        gearbox_type=article.find(attrs={'data-parameter':'gearbox'}).text.strip()
        print(gearbox_type)
                                      # year

        year=article.find('dl', class_="ooa-1omlbtp eszxync13")
        year=article.find(attrs={'data-parameter':'year'}).text.strip()
        print(year)

        cars.append([name,space,km,price,kilometrage,essence,gearbox_type,year])

                                          #FIAT
for i in range (1,10):
    url=f'https://www.otomoto.pl/osobowe/fiat?page=i'
    response=requests.get(url)
    response=response.content
    soup=BeautifulSoup(response,'html.parser')
    div=soup.find('div',class_="ooa-r53y0q ezh3mkl11")
    articles=div.find_all('article',class_='ooa-yca59n eszxync0')
    for article in articles:
                                               #name
        name=article.find('a').text
        print(name)
                                               #space
        space=article.find('p',class_='eszxync10 ooa-1tku07r er34gjf0').text
        space=space[:9]
        print(space)
                                               # kilometers
        km=article.find('p',class_='eszxync10 ooa-1tku07r er34gjf0').text
        km=km[13:18]
        print(km)
                                               #price
        price=article.find('h3',class_='eszxync16 ooa-1n2paoq er34gjf0').text
        price+=article.find('p',class_='eszxync17 ooa-8vn6i7 er34gjf0').text
        print(price)
      #                                          #kilometrage
        kilometrage=article.find('dd',class_='ooa-1omlbtp eszxync13').text
        print(kilometrage)
                                               #essence

        essence=article.find('dl', class_="ooa-1omlbtp eszxync13")
        essence=article.find(attrs={'data-parameter':"fuel_type"}).text.strip()
        print(essence)
                                               # gearbox_type==manuelle ou automatique

        gearbox_type=article.find('dl', class_="ooa-1omlbtp eszxync13")
        gearbox_type=article.find(attrs={'data-parameter':'gearbox'}).text.strip()
        print(gearbox_type)
                                      # year

        year=article.find('dl', class_="ooa-1omlbtp eszxync13")
        year=article.find(attrs={'data-parameter':'year'}).text.strip()
        print(year)

        cars.append([name,space,km,price,kilometrage,essence,gearbox_type,year])

                                                                   #AUDI
for i in range (1,10):
    url=f'https://www.otomoto.pl/osobowe/audi?page=i'
    response=requests.get(url)
    response=response.content
    soup=BeautifulSoup(response,'html.parser')
    div=soup.find('div',class_="ooa-r53y0q ezh3mkl11")
    articles=div.find_all('article',class_='ooa-yca59n eszxync0')
    for article in articles:
                                               #name
        name=article.find('a').text
        print(name)
                                               #space
        space=article.find('p',class_='eszxync10 ooa-1tku07r er34gjf0').text
        space=space[:9]
        print(space)
                                               # kilometers
        km=article.find('p',class_='eszxync10 ooa-1tku07r er34gjf0').text
        km=km[13:18]
        print(km)
                                               #price
        price=article.find('h3',class_='eszxync16 ooa-1n2paoq er34gjf0').text
        price+=article.find('p',class_='eszxync17 ooa-8vn6i7 er34gjf0').text
        print(price)
      #                                          #kilometrage
        kilometrage=article.find('dd',class_='ooa-1omlbtp eszxync13').text
        print(kilometrage)
                                               #essence

        essence=article.find('dl', class_="ooa-1omlbtp eszxync13")
        essence=article.find(attrs={'data-parameter':"fuel_type"}).text.strip()
        print(essence)
                                               # gearbox_type==manuelle ou automatique

        gearbox_type=article.find('dl', class_="ooa-1omlbtp eszxync13")
        gearbox_type=article.find(attrs={'data-parameter':'gearbox'}).text.strip()
        print(gearbox_type)
                                      # year

        year=article.find('dl', class_="ooa-1omlbtp eszxync13")
        year=article.find(attrs={'data-parameter':'year'}).text.strip()
        print(year)

        cars.append([name,space,km,price,kilometrage,essence,gearbox_type,year])

                                                   #citroen
for i in range (1,10):
    url=f'https://www.otomoto.pl/osobowe/citroen?page=i'
    response=requests.get(url)
    response=response.content
    soup=BeautifulSoup(response,'html.parser')
    div=soup.find('div',class_="ooa-r53y0q ezh3mkl11")
    articles=div.find_all('article',class_='ooa-yca59n eszxync0')
    for article in articles:
                                               #name
        name=article.find('a').text
        print(name)
                                               #space
        space=article.find('p',class_='eszxync10 ooa-1tku07r er34gjf0').text
        space=space[:9]
        print(space)
                                               # kilometers
        km=article.find('p',class_='eszxync10 ooa-1tku07r er34gjf0').text
        km=km[13:18]
        print(km)
                                               #price
        price=article.find('h3',class_='eszxync16 ooa-1n2paoq er34gjf0').text
        price+=article.find('p',class_='eszxync17 ooa-8vn6i7 er34gjf0').text
        print(price)
      #                                          #kilometrage
        kilometrage=article.find('dd',class_='ooa-1omlbtp eszxync13').text
        print(kilometrage)
                                               #essence

        essence=article.find('dl', class_="ooa-1omlbtp eszxync13")
        essence=article.find(attrs={'data-parameter':"fuel_type"}).text.strip()
        print(essence)
                                               # gearbox_type==manuelle ou automatique

        gearbox_type=article.find('dl', class_="ooa-1omlbtp eszxync13")
        gearbox_type=article.find(attrs={'data-parameter':'gearbox'}).text.strip()
        print(gearbox_type)
                                      # year

        year=article.find('dl', class_="ooa-1omlbtp eszxync13")
        year=article.find(attrs={'data-parameter':'year'}).text.strip()
        print(year)

        cars.append([name,space,km,price,kilometrage,essence,gearbox_type,year])

                                                    #FORD
for i in range (1,10):
    url=f'https://www.otomoto.pl/osobowe/ford?page=i'
    response=requests.get(url)
    response=response.content
    soup=BeautifulSoup(response,'html.parser')
    div=soup.find('div',class_="ooa-r53y0q ezh3mkl11")
    articles=div.find_all('article',class_='ooa-yca59n eszxync0')
    for article in articles:
                                               #name
        name=article.find('a').text
        print(name)
                                               #space
        space=article.find('p',class_='eszxync10 ooa-1tku07r er34gjf0').text
        space=space[:9]
        print(space)
                                               # kilometers
        km=article.find('p',class_='eszxync10 ooa-1tku07r er34gjf0').text
        km=km[13:18]
        print(km)
                                               #price
        price=article.find('h3',class_='eszxync16 ooa-1n2paoq er34gjf0').text
        price+=article.find('p',class_='eszxync17 ooa-8vn6i7 er34gjf0').text
        print(price)
      #                                          #kilometrage
        kilometrage=article.find('dd',class_='ooa-1omlbtp eszxync13').text
        print(kilometrage)
                                               #essence

        essence=article.find('dl', class_="ooa-1omlbtp eszxync13")
        essence=article.find(attrs={'data-parameter':"fuel_type"}).text.strip()
        print(essence)
                                               # gearbox_type==manuelle ou automatique

        gearbox_type=article.find('dl', class_="ooa-1omlbtp eszxync13")
        gearbox_type=article.find(attrs={'data-parameter':'gearbox'}).text.strip()
        print(gearbox_type)
                                      # year

        year=article.find('dl', class_="ooa-1omlbtp eszxync13")
        year=article.find(attrs={'data-parameter':'year'}).text.strip()
        print(year)

        cars.append([name,space,km,price,kilometrage,essence,gearbox_type,year])

                                                      #HYUNDAI
for i in range (1,10):
    url=f'https://www.otomoto.pl/osobowe/hyundai?page=i'
    response=requests.get(url)
    response=response.content
    soup=BeautifulSoup(response,'html.parser')
    div=soup.find('div',class_="ooa-r53y0q ezh3mkl11")
    articles=div.find_all('article',class_='ooa-yca59n eszxync0')
    for article in articles:
                                               #name
        name=article.find('a').text
        print(name)
                                               #space
        space=article.find('p',class_='eszxync10 ooa-1tku07r er34gjf0').text
        space=space[:9]
        print(space)
                                               # kilometers
        km=article.find('p',class_='eszxync10 ooa-1tku07r er34gjf0').text
        km=km[13:18]
        print(km)
                                               #price
        price=article.find('h3',class_='eszxync16 ooa-1n2paoq er34gjf0').text
        price+=article.find('p',class_='eszxync17 ooa-8vn6i7 er34gjf0').text
        print(price)
      #                                          #kilometrage
        kilometrage=article.find('dd',class_='ooa-1omlbtp eszxync13').text
        print(kilometrage)
                                               #essence

        essence=article.find('dl', class_="ooa-1omlbtp eszxync13")
        essence=article.find(attrs={'data-parameter':"fuel_type"}).text.strip()
        print(essence)
                                               # gearbox_type==manuelle ou automatique

        gearbox_type=article.find('dl', class_="ooa-1omlbtp eszxync13")
        gearbox_type=article.find(attrs={'data-parameter':'gearbox'}).text.strip()
        print(gearbox_type)
                                      # year

        year=article.find('dl', class_="ooa-1omlbtp eszxync13")
        year=article.find(attrs={'data-parameter':'year'}).text.strip()
        print(year)

        cars.append([name,space,km,price,kilometrage,essence,gearbox_type,year])

                                               #KIA
for i in range (1,10):
    url=f'https://www.otomoto.pl/osobowe/kia?page=i'
    response=requests.get(url)
    response=response.content
    soup=BeautifulSoup(response,'html.parser')
    div=soup.find('div',class_="ooa-r53y0q ezh3mkl11")
    articles=div.find_all('article',class_='ooa-yca59n eszxync0')
    for article in articles:
                                               #name
        name=article.find('a').text
        print(name)
                                               #space
        space=article.find('p',class_='eszxync10 ooa-1tku07r er34gjf0').text
        space=space[:9]
        print(space)
                                               # kilometers
        km=article.find('p',class_='eszxync10 ooa-1tku07r er34gjf0').text
        km=km[13:18]
        print(km)
                                               #price
        price=article.find('h3',class_='eszxync16 ooa-1n2paoq er34gjf0').text
        price+=article.find('p',class_='eszxync17 ooa-8vn6i7 er34gjf0').text
        print(price)
      #                                          #kilometrage
        kilometrage=article.find('dd',class_='ooa-1omlbtp eszxync13').text
        print(kilometrage)
                                               #essence

        essence=article.find('dl', class_="ooa-1omlbtp eszxync13")
        essence=article.find(attrs={'data-parameter':"fuel_type"}).text.strip()
        print(essence)
                                               # gearbox_type==manuelle ou automatique

        gearbox_type=article.find('dl', class_="ooa-1omlbtp eszxync13")
        gearbox_type=article.find(attrs={'data-parameter':'gearbox'}).text.strip()
        print(gearbox_type)
                                      # year

        year=article.find('dl', class_="ooa-1omlbtp eszxync13")
        year=article.find(attrs={'data-parameter':'year'}).text.strip()
        print(year)

        cars.append([name,space,km,price,kilometrage,essence,gearbox_type,year])


                                                    #MAZDA
for i in range (1,10):
    url=f'https://www.otomoto.pl/osobowe/mazda?page=i'
    response=requests.get(url)
    response=response.content
    soup=BeautifulSoup(response,'html.parser')
    div=soup.find('div',class_="ooa-r53y0q ezh3mkl11")
    articles=div.find_all('article',class_='ooa-yca59n eszxync0')
    for article in articles:
                                               #name
        name=article.find('a').text
        print(name)
                                               #space
        space=article.find('p',class_='eszxync10 ooa-1tku07r er34gjf0').text
        space=space[:9]
        print(space)
                                               # kilometers
        km=article.find('p',class_='eszxync10 ooa-1tku07r er34gjf0').text
        km=km[13:18]
        print(km)
                                               #price
        price=article.find('h3',class_='eszxync16 ooa-1n2paoq er34gjf0').text
        price+=article.find('p',class_='eszxync17 ooa-8vn6i7 er34gjf0').text
        print(price)
      #                                          #kilometrage
        kilometrage=article.find('dd',class_='ooa-1omlbtp eszxync13').text
        print(kilometrage)
                                               #essence

        essence=article.find('dl', class_="ooa-1omlbtp eszxync13")
        essence=article.find(attrs={'data-parameter':"fuel_type"}).text.strip()
        print(essence)
                                               # gearbox_type==manuelle ou automatique

        gearbox_type=article.find('dl', class_="ooa-1omlbtp eszxync13")
        gearbox_type=article.find(attrs={'data-parameter':'gearbox'}).text.strip()
        print(gearbox_type)
                                      # year

        year=article.find('dl', class_="ooa-1omlbtp eszxync13")
        year=article.find(attrs={'data-parameter':'year'}).text.strip()
        print(year)

        cars.append([name,space,km,price,kilometrage,essence,gearbox_type,year])

                                                    #OPEL
for i in range (1,10):
    url=f'https://www.otomoto.pl/osobowe/opel?page=i'
    response=requests.get(url)
    response=response.content
    soup=BeautifulSoup(response,'html.parser')
    div=soup.find('div',class_="ooa-r53y0q ezh3mkl11")
    articles=div.find_all('article',class_='ooa-yca59n eszxync0')
    for article in articles:
                                               #name
        name=article.find('a').text
        print(name)
                                               #space
        space=article.find('p',class_='eszxync10 ooa-1tku07r er34gjf0').text
        space=space[:9]
        print(space)
                                               # kilometers
        km=article.find('p',class_='eszxync10 ooa-1tku07r er34gjf0').text
        km=km[13:18]
        print(km)
                                               #price
        price=article.find('h3',class_='eszxync16 ooa-1n2paoq er34gjf0').text
        price+=article.find('p',class_='eszxync17 ooa-8vn6i7 er34gjf0').text
        print(price)
      #                                          #kilometrage
        kilometrage=article.find('dd',class_='ooa-1omlbtp eszxync13').text
        print(kilometrage)
                                               #essence

        essence=article.find('dl', class_="ooa-1omlbtp eszxync13")
        essence=article.find(attrs={'data-parameter':"fuel_type"}).text.strip()
        print(essence)
                                               # gearbox_type==manuelle ou automatique

        gearbox_type=article.find('dl', class_="ooa-1omlbtp eszxync13")
        gearbox_type=article.find(attrs={'data-parameter':'gearbox'}).text.strip()
        print(gearbox_type)
                                      # year

        year=article.find('dl', class_="ooa-1omlbtp eszxync13")
        year=article.find(attrs={'data-parameter':'year'}).text.strip()
        print(year)

        cars.append([name,space,km,price,kilometrage,essence,gearbox_type,year])

                                                          #PEUGEOT

for i in range (1,10):
    url=f'https://www.otomoto.pl/osobowe/peugeot?page=i'
    response=requests.get(url)
    response=response.content
    soup=BeautifulSoup(response,'html.parser')
    div=soup.find('div',class_="ooa-r53y0q ezh3mkl11")
    articles=div.find_all('article',class_='ooa-yca59n eszxync0')
    for article in articles:
                                               #name
        name=article.find('a').text
        print(name)
                                               #space
        space=article.find('p',class_='eszxync10 ooa-1tku07r er34gjf0').text
        space=space[:9]
        print(space)
                                               # kilometers
        km=article.find('p',class_='eszxync10 ooa-1tku07r er34gjf0').text
        km=km[13:18]
        print(km)
                                               #price
        price=article.find('h3',class_='eszxync16 ooa-1n2paoq er34gjf0').text
        price+=article.find('p',class_='eszxync17 ooa-8vn6i7 er34gjf0').text
        print(price)
      #                                          #kilometrage
        kilometrage=article.find('dd',class_='ooa-1omlbtp eszxync13').text
        print(kilometrage)
                                               #essence

        essence=article.find('dl', class_="ooa-1omlbtp eszxync13")
        essence=article.find(attrs={'data-parameter':"fuel_type"}).text.strip()
        print(essence)
                                               # gearbox_type==manuelle ou automatique

        gearbox_type=article.find('dl', class_="ooa-1omlbtp eszxync13")
        gearbox_type=article.find(attrs={'data-parameter':'gearbox'}).text.strip()
        print(gearbox_type)
                                      # year

        year=article.find('dl', class_="ooa-1omlbtp eszxync13")
        year=article.find(attrs={'data-parameter':'year'}).text.strip()
        print(year)

        cars.append([name,space,km,price,kilometrage,essence,gearbox_type,year])

                                                            #RENAULT
for i in range (1,10):
    url=f'https://www.otomoto.pl/osobowe/renault?page=i'
    response=requests.get(url)
    response=response.content
    soup=BeautifulSoup(response,'html.parser')
    div=soup.find('div',class_="ooa-r53y0q ezh3mkl11")
    articles=div.find_all('article',class_='ooa-yca59n eszxync0')
    for article in articles:
                                               #name
        name=article.find('a').text
        print(name)
                                               #space
        space=article.find('p',class_='eszxync10 ooa-1tku07r er34gjf0').text
        space=space[:9]
        print(space)
                                               # kilometers
        km=article.find('p',class_='eszxync10 ooa-1tku07r er34gjf0').text
        km=km[13:18]
        print(km)
                                               #price
        price=article.find('h3',class_='eszxync16 ooa-1n2paoq er34gjf0').text
        price+=article.find('p',class_='eszxync17 ooa-8vn6i7 er34gjf0').text
        print(price)
      #                                          #kilometrage
        kilometrage=article.find('dd',class_='ooa-1omlbtp eszxync13').text
        print(kilometrage)
                                               #essence

        essence=article.find('dl', class_="ooa-1omlbtp eszxync13")
        essence=article.find(attrs={'data-parameter':"fuel_type"}).text.strip()
        print(essence)
                                               # gearbox_type==manuelle ou automatique

        gearbox_type=article.find('dl', class_="ooa-1omlbtp eszxync13")
        gearbox_type=article.find(attrs={'data-parameter':'gearbox'}).text.strip()
        print(gearbox_type)
                                      # year

        year=article.find('dl', class_="ooa-1omlbtp eszxync13")
        year=article.find(attrs={'data-parameter':'year'}).text.strip()
        print(year)

        cars.append([name,space,km,price,kilometrage,essence,gearbox_type,year])

                                                          #SEAT
for i in range (1,10):
    url=f'https://www.otomoto.pl/osobowe/seat?page=i'
    response=requests.get(url)
    response=response.content
    soup=BeautifulSoup(response,'html.parser')
    div=soup.find('div',class_="ooa-r53y0q ezh3mkl11")
    articles=div.find_all('article',class_='ooa-yca59n eszxync0')
    for article in articles:
                                               #name
        name=article.find('a').text
        print(name)
                                               #space
        space=article.find('p',class_='eszxync10 ooa-1tku07r er34gjf0').text
        space=space[:9]
        print(space)
                                               # kilometers
        km=article.find('p',class_='eszxync10 ooa-1tku07r er34gjf0').text
        km=km[13:18]
        print(km)
                                               #price
        price=article.find('h3',class_='eszxync16 ooa-1n2paoq er34gjf0').text
        price+=article.find('p',class_='eszxync17 ooa-8vn6i7 er34gjf0').text
        print(price)
      #                                          #kilometrage
        kilometrage=article.find('dd',class_='ooa-1omlbtp eszxync13').text
        print(kilometrage)
                                               #essence

        essence=article.find('dl', class_="ooa-1omlbtp eszxync13")
        essence=article.find(attrs={'data-parameter':"fuel_type"}).text.strip()
        print(essence)
                                               # gearbox_type==manuelle ou automatique

        gearbox_type=article.find('dl', class_="ooa-1omlbtp eszxync13")
        gearbox_type=article.find(attrs={'data-parameter':'gearbox'}).text.strip()
        print(gearbox_type)
                                      # year

        year=article.find('dl', class_="ooa-1omlbtp eszxync13")
        year=article.find(attrs={'data-parameter':'year'}).text.strip()
        print(year)

        cars.append([name,space,km,price,kilometrage,essence,gearbox_type,year])


                                                              #SKODA
for i in range (1,10):
    url=f'https://www.otomoto.pl/osobowe/skoda?page=i'
    response=requests.get(url)
    response=response.content
    soup=BeautifulSoup(response,'html.parser')
    div=soup.find('div',class_="ooa-r53y0q ezh3mkl11")
    articles=div.find_all('article',class_='ooa-yca59n eszxync0')
    for article in articles:
                                               #name
        name=article.find('a').text
        print(name)
                                               #space
        space=article.find('p',class_='eszxync10 ooa-1tku07r er34gjf0').text
        space=space[:9]
        print(space)
                                               # kilometers
        km=article.find('p',class_='eszxync10 ooa-1tku07r er34gjf0').text
        km=km[13:18]
        print(km)
                                               #price
        price=article.find('h3',class_='eszxync16 ooa-1n2paoq er34gjf0').text
        price+=article.find('p',class_='eszxync17 ooa-8vn6i7 er34gjf0').text
        print(price)
      #                                          #kilometrage
        kilometrage=article.find('dd',class_='ooa-1omlbtp eszxync13').text
        print(kilometrage)
                                               #essence

        essence=article.find('dl', class_="ooa-1omlbtp eszxync13")
        essence=article.find(attrs={'data-parameter':"fuel_type"}).text.strip()
        print(essence)
                                               # gearbox_type==manuelle ou automatique

        gearbox_type=article.find('dl', class_="ooa-1omlbtp eszxync13")
        gearbox_type=article.find(attrs={'data-parameter':'gearbox'}).text.strip()
        print(gearbox_type)
                                      # year

        year=article.find('dl', class_="ooa-1omlbtp eszxync13")
        year=article.find(attrs={'data-parameter':'year'}).text.strip()
        print(year)

        cars.append([name,space,km,price,kilometrage,essence,gearbox_type,year])

                                                      #TOYOTA
for i in range (1,10):
    url=f'https://www.otomoto.pl/osobowe/toyota?page=i'
    response=requests.get(url)
    response=response.content
    soup=BeautifulSoup(response,'html.parser')
    div=soup.find('div',class_="ooa-r53y0q ezh3mkl11")
    articles=div.find_all('article',class_='ooa-yca59n eszxync0')
    for article in articles:
                                               #name
        name=article.find('a').text
        print(name)
                                               #space
        space=article.find('p',class_='eszxync10 ooa-1tku07r er34gjf0').text
        space=space[:9]
        print(space)
                                               # kilometers
        km=article.find('p',class_='eszxync10 ooa-1tku07r er34gjf0').text
        km=km[13:18]
        print(km)
                                               #price
        price=article.find('h3',class_='eszxync16 ooa-1n2paoq er34gjf0').text
        price+=article.find('p',class_='eszxync17 ooa-8vn6i7 er34gjf0').text
        print(price)
      #                                          #kilometrage
        kilometrage=article.find('dd',class_='ooa-1omlbtp eszxync13').text
        print(kilometrage)
                                               #essence

        essence=article.find('dl', class_="ooa-1omlbtp eszxync13")
        essence=article.find(attrs={'data-parameter':"fuel_type"}).text.strip()
        print(essence)
                                               # gearbox_type==manuelle ou automatique

        gearbox_type=article.find('dl', class_="ooa-1omlbtp eszxync13")
        gearbox_type=article.find(attrs={'data-parameter':'gearbox'}).text.strip()
        print(gearbox_type)
                                      # year

        year=article.find('dl', class_="ooa-1omlbtp eszxync13")
        year=article.find(attrs={'data-parameter':'year'}).text.strip()
        print(year)

        cars.append([name,space,km,price,kilometrage,essence,gearbox_type,year])



                                                          #VOLVO
for i in range (1,10):
    url=f'https://www.otomoto.pl/osobowe/volvo?page=i'
    response=requests.get(url)
    response=response.content
    soup=BeautifulSoup(response,'html.parser')
    div=soup.find('div',class_="ooa-r53y0q ezh3mkl11")
    articles=div.find_all('article',class_='ooa-yca59n eszxync0')
    for article in articles:
                                               #name
        name=article.find('a').text
        print(name)
                                               #space
        space=article.find('p',class_='eszxync10 ooa-1tku07r er34gjf0').text
        space=space[:9]
        print(space)
                                               # kilometers
        km=article.find('p',class_='eszxync10 ooa-1tku07r er34gjf0').text
        km=km[13:18]
        print(km)
                                               #price
        price=article.find('h3',class_='eszxync16 ooa-1n2paoq er34gjf0').text
        price+=article.find('p',class_='eszxync17 ooa-8vn6i7 er34gjf0').text
        print(price)
      #                                          #kilometrage
        kilometrage=article.find('dd',class_='ooa-1omlbtp eszxync13').text
        print(kilometrage)
                                               #essence

        essence=article.find('dl', class_="ooa-1omlbtp eszxync13")
        essence=article.find(attrs={'data-parameter':"fuel_type"}).text.strip()
        print(essence)
                                               # gearbox_type==manuelle ou automatique

        gearbox_type=article.find('dl', class_="ooa-1omlbtp eszxync13")
        gearbox_type=article.find(attrs={'data-parameter':'gearbox'}).text.strip()
        print(gearbox_type)
                                      # year

        year=article.find('dl', class_="ooa-1omlbtp eszxync13")
        year=article.find(attrs={'data-parameter':'year'}).text.strip()
        print(year)

        cars.append([name,space,km,price,kilometrage,essence,gearbox_type,year])

                                                         #DACIA

for i in range (1,10):
    url=f'https://www.otomoto.pl/osobowe/dacia?page=i'
    response=requests.get(url)
    response=response.content
    soup=BeautifulSoup(response,'html.parser')
    div=soup.find('div',class_="ooa-r53y0q ezh3mkl11")
    articles=div.find_all('article',class_='ooa-yca59n eszxync0')
    for article in articles:
                                               #name
        name=article.find('a').text
        print(name)
                                               #space
        space=article.find('p',class_='eszxync10 ooa-1tku07r er34gjf0').text
        space=space[:9]
        print(space)
                                               # kilometers
        km=article.find('p',class_='eszxync10 ooa-1tku07r er34gjf0').text
        km=km[13:18]
        print(km)
                                               #price
        price=article.find('h3',class_='eszxync16 ooa-1n2paoq er34gjf0').text
        price+=article.find('p',class_='eszxync17 ooa-8vn6i7 er34gjf0').text
        print(price)
      #                                          #kilometrage
        kilometrage=article.find('dd',class_='ooa-1omlbtp eszxync13').text
        print(kilometrage)
                                               #essence

        essence=article.find('dl', class_="ooa-1omlbtp eszxync13")
        essence=article.find(attrs={'data-parameter':"fuel_type"}).text.strip()
        print(essence)
                                               # gearbox_type==manuelle ou automatique

        gearbox_type=article.find('dl', class_="ooa-1omlbtp eszxync13")
        gearbox_type=article.find(attrs={'data-parameter':'gearbox'}).text.strip()
        print(gearbox_type)
                                      # year

        year=article.find('dl', class_="ooa-1omlbtp eszxync13")
        year=article.find(attrs={'data-parameter':'year'}).text.strip()
        print(year)

        cars.append([name,space,km,price,kilometrage,essence,gearbox_type,year])

                                                       #mercedes-benz

for i in range (1,10):
    url=f'https://www.otomoto.pl/osobowe/mercedes-benz?page=i'
    response=requests.get(url)
    response=response.content
    soup=BeautifulSoup(response,'html.parser')
    div=soup.find('div',class_="ooa-r53y0q ezh3mkl11")
    articles=div.find_all('article',class_='ooa-yca59n eszxync0')
    for article in articles:
                                               #name
        name=article.find('a').text
        print(name)
                                               #space
        space=article.find('p',class_='eszxync10 ooa-1tku07r er34gjf0').text
        space=space[:9]
        print(space)
                                               # kilometers
        km=article.find('p',class_='eszxync10 ooa-1tku07r er34gjf0').text
        km=km[13:18]
        print(km)
                                               #price
        price=article.find('h3',class_='eszxync16 ooa-1n2paoq er34gjf0').text
        price+=article.find('p',class_='eszxync17 ooa-8vn6i7 er34gjf0').text
        print(price)
      #                                          #kilometrage
        kilometrage=article.find('dd',class_='ooa-1omlbtp eszxync13').text
        print(kilometrage)
                                               #essence

        essence=article.find('dl', class_="ooa-1omlbtp eszxync13")
        essence=article.find(attrs={'data-parameter':"fuel_type"}).text.strip()
        print(essence)
                                               # gearbox_type==manuelle ou automatique

        gearbox_type=article.find('dl', class_="ooa-1omlbtp eszxync13")
        gearbox_type=article.find(attrs={'data-parameter':'gearbox'}).text.strip()
        print(gearbox_type)
                                      # year

        year=article.find('dl', class_="ooa-1omlbtp eszxync13")
        year=article.find(attrs={'data-parameter':'year'}).text.strip()
        print(year)

        cars.append([name,space,km,price,kilometrage,essence,gearbox_type,year])

df=pd.DataFrame(cars,columns=['Car_Name','Engine capacity','Power','Price','Mileage','Fuel_Type','Gearbox_Type','Year_Of_Production'])
df.to_csv('CARS.csv')
# Out:
# Le flux de sortie a été tronqué et ne contient que les 5000 dernières lignes.
# Volvo XC 90 T6 AWD Momentum 7os
# 1 969 cm3
# 20 KM
# 154 750PLN
# 60 000 km
# Benzyna
# Automatyczna
# 2018
# Volvo V40 D4 Summum
# 1 969 cm3
# 90 KM
# 42 000PLN
# 210 000 km
# Diesel
# Manualna
# 2014
# Volvo XC 90
# 1 969 cm3
# 10 KM
# 253 000PLN
# 15 800 km
# Hybryda Plug-in
# Automatyczna
# 2022
# Volvo V60 D4 Drive-E R-Design Momentum
# 1 969 cm3
# 90 KM
# 79 888PLN
# 144 700 km
# Diesel
# Manualna
# 2017
# Volvo XC 60
# 1 969 cm3
# 90 KM
# 123 900PLN
# 35 000 km
# Benzyna
# Automatyczna
# 2020
# Volvo XC 90 B5 D AWD Geartronic RDesign
# 1 969 cm3
# 35 KM
# 181 000PLN
# 138 000 km
# Diesel
# Automatyczna
# 2019
#
# 1 969 cm3
# 50 KM
# 102 800PLN
# 158 000 km
# Diesel
# Automatyczna
# 2020
# Volvo XC 60 D4 Inscription
# 1 969 cm3
# 90 KM
# 67 900PLN
# 230 000 km
# Diesel
# Automatyczna
# 2019
# Volvo S80 D4 Geartronic Summum
# 1 969 cm3
# 81 KM
# 75 000PLN
# 168 000 km
# Diesel
# Automatyczna
# 2015
# Volvo V40 CC D3 Drive-E SCR Momentum
# 1 969 cm3
# 50 KM
# 62 500PLN
# 128 200 km
# Diesel
# Automatyczna
# 2016
# Volvo V90 D4 Geartronic Momentum Pro
# 1 969 cm3
# 90 KM
# 138 800PLN
# 37 700 km
# Diesel
# Automatyczna
# 2019
# Volvo XC 60 D5 AWD R-Design
# 2 400 cm3
# 05 KM
# 44 280PLN
# 376 000 km
# Diesel
# Manualna
# 2011
#
# 272 KM •
# 0 WAL
# 217 600PLN
# 10 km
# Elektryczny
# Automatyczna
# 2024
# Volvo XC 60 T6 AWD Inscription
# 1 969 cm3
# 10 KM
# 169 000PLN
# 23 853 km
# Benzyna
# Automatyczna
# 2020
# Volvo XC 60 D5 AWD RDesign
# 2 400 cm3
# 05 KM
# 37 900PLN
# 432 000 km
# Diesel
# Automatyczna
# 2011
# Volvo V60 Cross Country D4 Drive-E Momentum
# 1 969 cm3
# 90 KM
# 79 900PLN
# 190 000 km
# Diesel
# Automatyczna
# 2018
# Volvo XC 60 D3 Momentum
# 1 984 cm3
# 36 KM
# 43 500PLN
# 275 000 km
# Diesel
# Manualna
# 2012
# Volvo V50 2.0D
# 1 998 cm3
# 36 KM
# 8 700PLN
# 362 000 km
# Diesel
# Manualna
# 2005
# Volvo XC 60 D3 Momentum Pro
# 1 969 cm3
# 50 KM
# 102 700PLN
# 132 000 km
# Diesel
# Manualna
# 2019
# Volvo V50 1.6D
# 1 560 cm3
# 09 KM
# 12 000PLN
# 320 000 km
# Diesel
# Manualna
# 2006
# Volvo XC 60
# 1 969 cm3
# 90 KM
# 129 800PLN
# 112 000 km
# Diesel
# Automatyczna
# 2020
# Volvo V60 D3 Geartronic Momentum
# 1 969 cm3
# 49 KM
# 104 999PLN
# 158 000 km
# Diesel
# Automatyczna
# 2018
# Volvo V60 D4 Momentum
# 1 969 cm3
# 90 KM
# 58 800PLN
# 139 000 km
# Diesel
# Automatyczna
# 2016
# Volvo V90 Cross Country D4 AWD Geartronic Pro
# 1 969 cm3
# 90 KM
# 107 900PLN
# 221 000 km
# Diesel
# Automatyczna
# 2018
# Volvo XC 90 4.4 V8 Summum
# 4 414 cm3
# 15 KM
# 35 000PLN
# 339 000 km
# Benzyna+LPG
# Automatyczna
# 2005
# Volvo V50
# 1 998 cm3
# 36 KM
# 13 999PLN
# 221 600 km
# Diesel
# Manualna
# 2005
# Volvo XC 40 T3 Momentum Pro
# 1 477 cm3
# 63 KM
# 135 000PLN
# 37 000 km
# Benzyna
# Automatyczna
# 2021
# Volvo V60 D4 Momentum
# 1 984 cm3
# 63 KM
# 32 900PLN
# 285 500 km
# Diesel
# Manualna
# 2011
# Volvo XC 60 T6 AWD Inscription
# 1 969 cm3
# 10 KM
# 134 900PLN
# 76 500 km
# Benzyna
# Automatyczna
# 2019
# Volvo XC 60 T8 AWD Plug-In Hybrid Momentum
# 1 969 cm3
# 20 KM
# 178 000PLN
# 125 000 km
# Hybryda Plug-in
# Automatyczna
# 2019
# Volvo S60 D3 RDesign
# 1 984 cm3
# 36 KM
# 59 900PLN
# 192 000 km
# Diesel
# Manualna
# 2014
# Volvo XC 90 D5 AWD Executive
# 2 401 cm3
# 85 KM
# 62 000PLN
# 251 000 km
# Diesel
# Automatyczna
# 2009
# Volvo XC 90 T6 AWD Momentum 7os
# 1 969 cm3
# 20 KM
# 154 750PLN
# 60 000 km
# Benzyna
# Automatyczna
# 2018
# Volvo V40 D4 Summum
# 1 969 cm3
# 90 KM
# 42 000PLN
# 210 000 km
# Diesel
# Manualna
# 2014
# Volvo XC 90
# 1 969 cm3
# 10 KM
# 253 000PLN
# 15 800 km
# Hybryda Plug-in
# Automatyczna
# 2022
# Volvo V60 D4 Drive-E R-Design Momentum
# 1 969 cm3
# 90 KM
# 79 888PLN
# 144 700 km
# Diesel
# Manualna
# 2017
# Volvo XC 60
# 1 969 cm3
# 90 KM
# 123 900PLN
# 35 000 km
# Benzyna
# Automatyczna
# 2020
# Volvo XC 90 B5 D AWD Geartronic RDesign
# 1 969 cm3
# 35 KM
# 181 000PLN
# 138 000 km
# Diesel
# Automatyczna
# 2019
#
# 1 969 cm3
# 50 KM
# 102 800PLN
# 158 000 km
# Diesel
# Automatyczna
# 2020
# Volvo XC 60 D4 Inscription
# 1 969 cm3
# 90 KM
# 67 900PLN
# 230 000 km
# Diesel
# Automatyczna
# 2019
# Volvo S80 D4 Geartronic Summum
# 1 969 cm3
# 81 KM
# 75 000PLN
# 168 000 km
# Diesel
# Automatyczna
# 2015
# Volvo V40 CC D3 Drive-E SCR Momentum
# 1 969 cm3
# 50 KM
# 62 500PLN
# 128 200 km
# Diesel
# Automatyczna
# 2016
# Volvo V90 D4 Geartronic Momentum Pro
# 1 969 cm3
# 90 KM
# 138 800PLN
# 37 700 km
# Diesel
# Automatyczna
# 2019
# Volvo XC 60 D5 AWD R-Design
# 2 400 cm3
# 05 KM
# 44 280PLN
# 376 000 km
# Diesel
# Manualna
# 2011
#
# 272 KM •
# 0 WAL
# 217 600PLN
# 10 km
# Elektryczny
# Automatyczna
# 2024
# Volvo XC 60 T6 AWD Inscription
# 1 969 cm3
# 10 KM
# 169 000PLN
# 23 853 km
# Benzyna
# Automatyczna
# 2020
# Volvo XC 60 D5 AWD RDesign
# 2 400 cm3
# 05 KM
# 37 900PLN
# 432 000 km
# Diesel
# Automatyczna
# 2011
# Volvo V60 Cross Country D4 Drive-E Momentum
# 1 969 cm3
# 90 KM
# 79 900PLN
# 190 000 km
# Diesel
# Automatyczna
# 2018
# Volvo XC 60 D3 Momentum
# 1 984 cm3
# 36 KM
# 43 500PLN
# 275 000 km
# Diesel
# Manualna
# 2012
# Dacia Lodgy dCi 110 Stepway
# 1 461 cm3
# 09 KM
# 20 999PLN
# 218 000 km
# Diesel
# Manualna
# 2016
# Dacia Duster 1.0 TCe Prestige
# 999 cm3 •
#  KM
# 71 000PLN
# 32 400 km
# Benzyna+LPG
# Manualna
# 2021
# Dacia Duster 1.6 SCe Laureate S&S
# 1 598 cm3
# 14 KM
# 55 200PLN
# 122 142 km
# Benzyna
# Manualna
# 2019
# Dacia Duster
# 1 461 cm3
# 15 KM
# 34 900PLN
# 33 908 km
# Diesel
# Manualna
# 2022
# Dacia Duster
# 1 332 cm3
# 30 KM
# 52 000PLN
# 70 554 km
# Benzyna
# Manualna
# 2019
# Dacia Sandero Stepway
# 1 461 cm3
# 0 KM
# 11 900PLN
# 183 000 km
# Diesel
# Manualna
# 2013
# Dacia Sandero 1.0 TCe Expression
# 999 cm3 •
# KM •
# 49 999PLN
# 85 000 km
# Benzyna
# Manualna
# 2021
# Dacia Duster 1.3 TCe SL Extreme 4WD
# 1 332 cm3
# 50 KM
# 95 000PLN
# 13 800 km
# Benzyna
# Manualna
# 2023
# Dacia Duster 1.5 dCi Laureate 4x4
# 1 461 cm3
# 10 KM
# 25 900PLN
# 211 000 km
# Diesel
# Manualna
# 2012
# Dacia Duster Blue dCi 115 4WD Expression
# 1 461 cm3
# 14 KM
# 59 700PLN
# 26 000 km
# Diesel
# Manualna
# 2022
# Dacia Sandero Stepway
# 1 461 cm3
# 0 KM
# 23 800PLN
# 188 000 km
# Diesel
# Manualna
# 2015
# Dacia Duster
# 1 461 cm3
# 16 KM
# 62 000PLN
# 29 000 km
# Diesel
# Manualna
# 2021
#
# 999 cm3 •
# KM •
# 86 301PLN
# 1 km
# Benzyna+LPG
# Manualna
# 2023
# Dacia Logan MCV 0.9 TCE Prestige
# 898 cm3 •
# KM •
# 19 781PLN
# 169 517 km
# Benzyna
# Manualna
# 2013
# Dacia Dokker
# 1 461 cm3
# 5 KM
# 24 171PLN
# 146 383 km
# Diesel
# Manualna
# 2016
# Dacia Duster
# 999 cm3 •
#  KM •
# 59 900PLN
# 81 212 km
# Benzyna+LPG
# Manualna
# 2020
# Dacia Duster 1.0 TCe SL Celebration
# 999 cm3 •
# KM •
# 59 900PLN
# 45 000 km
# Benzyna+LPG
# Manualna
# 2020
# Dacia Duster
# 999 cm3 •
# KM •
# 96 800PLN
# 10 km
# Benzyna+LPG
# Manualna
# 2024
# Dacia Duster 1.6 SCe Laureate S&S
# 1 598 cm3
# 14 KM
# 56 900PLN
# 90 150 km
# Benzyna
# Manualna
# 2018
# Dacia Duster
# 1 598 cm3
# 14 KM
# 64 900PLN
# 47 200 km
# Benzyna
# Manualna
# 2019
# Dacia Duster
# 999 cm3 •
#  KM •
# 55 900PLN
# 98 100 km
# Benzyna+LPG
# Manualna
# 2021
# Dacia Duster 1.5 dCi SL Off-Road 4x4
# 1 461 cm3
# 10 KM
# 28 500PLN
# 180 000 km
# Diesel
# Manualna
# 2012
# Dacia Sandero Stepway TCe 90 Prestige
# 898 cm3 •
# KM •
# 29 900PLN
# 60 000 km
# Benzyna
# Manualna
# 2013
# Dacia Dokker 1.2 TCe Outdoor
# 1 197 cm3
# 15 KM
# 43 050PLN
# 118 000 km
# Benzyna+LPG
# Manualna
# 2018
# Dacia Sandero Stepway
# 999 cm3 •
#  KM •
# 27 900PLN
# 13 000 km
# Benzyna
# Manualna
# 2021
#
# 1 598 cm3
# 15 KM
# 52 900PLN
# 204 204 km
# Benzyna
# Manualna
# 2019
# Dacia Duster
# 999 cm3 •
# KM •
# 79 990PLN
# 8 097 km
# Benzyna+LPG
# Manualna
# 2023
# Dacia Sandero 1.2 16V 75 Ambiance
# 1 149 cm3
# 5 KM
# 9 900PLN
# 174 188 km
# Benzyna
# Manualna
# 2009
#
# 999 cm3 •
#  KM •
# 92 350PLN
# 1 km
# Benzyna
# Manualna
# 2023
# Dacia Logan Van
# 1 197 cm3
# 15 KM
# 15 500PLN
# 70 500 km
# Benzyna
# Manualna
# 2018
# Dacia Dokker 1.6 MPI 85 Ambiance
# 1 598 cm3
# 3 KM
# 28 900PLN
# 205 362 km
# Benzyna+LPG
# Manualna
# 2014
#
# 999 cm3 •
#  KM •
# 89 000PLN
# 1 km
# Benzyna+LPG
# Manualna
# 2023
# Dacia Lodgy dCi 110 Stepway
# 1 461 cm3
# 09 KM
# 20 999PLN
# 218 000 km
# Diesel
# Manualna
# 2016
# Dacia Duster 1.0 TCe Prestige
# 999 cm3 •
#  KM
# 71 000PLN
# 32 400 km
# Benzyna+LPG
# Manualna
# 2021
# Dacia Duster 1.6 SCe Laureate S&S
# 1 598 cm3
# 14 KM
# 55 200PLN
# 122 142 km
# Benzyna
# Manualna
# 2019
# Dacia Duster
# 1 461 cm3
# 15 KM
# 34 900PLN
# 33 908 km
# Diesel
# Manualna
# 2022
# Dacia Duster
# 1 332 cm3
# 30 KM
# 52 000PLN
# 70 554 km
# Benzyna
# Manualna
# 2019
# Dacia Sandero Stepway
# 1 461 cm3
# 0 KM
# 11 900PLN
# 183 000 km
# Diesel
# Manualna
# 2013
# Dacia Sandero 1.0 TCe Expression
# 999 cm3 •
# KM •
# 49 999PLN
# 85 000 km
# Benzyna
# Manualna
# 2021
# Dacia Duster 1.3 TCe SL Extreme 4WD
# 1 332 cm3
# 50 KM
# 95 000PLN
# 13 800 km
# Benzyna
# Manualna
# 2023
# Dacia Duster 1.5 dCi Laureate 4x4
# 1 461 cm3
# 10 KM
# 25 900PLN
# 211 000 km
# Diesel
# Manualna
# 2012
# Dacia Duster Blue dCi 115 4WD Expression
# 1 461 cm3
# 14 KM
# 59 700PLN
# 26 000 km
# Diesel
# Manualna
# 2022
# Dacia Sandero Stepway
# 1 461 cm3
# 0 KM
# 23 800PLN
# 188 000 km
# Diesel
# Manualna
# 2015
# Dacia Duster
# 1 461 cm3
# 16 KM
# 62 000PLN
# 29 000 km
# Diesel
# Manualna
# 2021
#
# 999 cm3 •
# KM •
# 86 301PLN
# 1 km
# Benzyna+LPG
# Manualna
# 2023
# Dacia Logan MCV 0.9 TCE Prestige
# 898 cm3 •
# KM •
# 19 781PLN
# 169 517 km
# Benzyna
# Manualna
# 2013
# Dacia Dokker
# 1 461 cm3
# 5 KM
# 24 171PLN
# 146 383 km
# Diesel
# Manualna
# 2016
# Dacia Duster
# 999 cm3 •
#  KM •
# 59 900PLN
# 81 212 km
# Benzyna+LPG
# Manualna
# 2020
# Dacia Duster 1.0 TCe SL Celebration
# 999 cm3 •
# KM •
# 59 900PLN
# 45 000 km
# Benzyna+LPG
# Manualna
# 2020
# Dacia Duster
# 999 cm3 •
# KM •
# 96 800PLN
# 10 km
# Benzyna+LPG
# Manualna
# 2024
# Dacia Duster 1.6 SCe Laureate S&S
# 1 598 cm3
# 14 KM
# 56 900PLN
# 90 150 km
# Benzyna
# Manualna
# 2018
# Dacia Duster
# 1 598 cm3
# 14 KM
# 64 900PLN
# 47 200 km
# Benzyna
# Manualna
# 2019
# Dacia Duster
# 999 cm3 •
#  KM •
# 55 900PLN
# 98 100 km
# Benzyna+LPG
# Manualna
# 2021
# Dacia Duster 1.5 dCi SL Off-Road 4x4
# 1 461 cm3
# 10 KM
# 28 500PLN
# 180 000 km
# Diesel
# Manualna
# 2012
# Dacia Sandero Stepway TCe 90 Prestige
# 898 cm3 •
# KM •
# 29 900PLN
# 60 000 km
# Benzyna
# Manualna
# 2013
# Dacia Dokker 1.2 TCe Outdoor
# 1 197 cm3
# 15 KM
# 43 050PLN
# 118 000 km
# Benzyna+LPG
# Manualna
# 2018
# Dacia Sandero Stepway
# 999 cm3 •
#  KM •
# 27 900PLN
# 13 000 km
# Benzyna
# Manualna
# 2021
#
# 1 598 cm3
# 15 KM
# 52 900PLN
# 204 204 km
# Benzyna
# Manualna
# 2019
# Dacia Duster
# 999 cm3 •
# KM •
# 79 990PLN
# 8 097 km
# Benzyna+LPG
# Manualna
# 2023
# Dacia Sandero 1.2 16V 75 Ambiance
# 1 149 cm3
# 5 KM
# 9 900PLN
# 174 188 km
# Benzyna
# Manualna
# 2009
#
# 999 cm3 •
#  KM •
# 92 350PLN
# 1 km
# Benzyna
# Manualna
# 2023
# Dacia Logan Van
# 1 197 cm3
# 15 KM
# 15 500PLN
# 70 500 km
# Benzyna
# Manualna
# 2018
# Dacia Dokker 1.6 MPI 85 Ambiance
# 1 598 cm3
# 3 KM
# 28 900PLN
# 205 362 km
# Benzyna+LPG
# Manualna
# 2014
#
# 999 cm3 •
#  KM •
# 89 000PLN
# 1 km
# Benzyna+LPG
# Manualna
# 2023
# Dacia Lodgy dCi 110 Stepway
# 1 461 cm3
# 09 KM
# 20 999PLN
# 218 000 km
# Diesel
# Manualna
# 2016
# Dacia Duster 1.0 TCe Prestige
# 999 cm3 •
#  KM
# 71 000PLN
# 32 400 km
# Benzyna+LPG
# Manualna
# 2021
# Dacia Duster 1.6 SCe Laureate S&S
# 1 598 cm3
# 14 KM
# 55 200PLN
# 122 142 km
# Benzyna
# Manualna
# 2019
# Dacia Duster
# 1 461 cm3
# 15 KM
# 34 900PLN
# 33 908 km
# Diesel
# Manualna
# 2022
# Dacia Duster
# 1 332 cm3
# 30 KM
# 52 000PLN
# 70 554 km
# Benzyna
# Manualna
# 2019
# Dacia Sandero Stepway
# 1 461 cm3
# 0 KM
# 11 900PLN
# 183 000 km
# Diesel
# Manualna
# 2013
# Dacia Sandero 1.0 TCe Expression
# 999 cm3 •
# KM •
# 49 999PLN
# 85 000 km
# Benzyna
# Manualna
# 2021
# Dacia Duster 1.3 TCe SL Extreme 4WD
# 1 332 cm3
# 50 KM
# 95 000PLN
# 13 800 km
# Benzyna
# Manualna
# 2023
# Dacia Duster 1.5 dCi Laureate 4x4
# 1 461 cm3
# 10 KM
# 25 900PLN
# 211 000 km
# Diesel
# Manualna
# 2012
# Dacia Duster Blue dCi 115 4WD Expression
# 1 461 cm3
# 14 KM
# 59 700PLN
# 26 000 km
# Diesel
# Manualna
# 2022
# Dacia Sandero Stepway
# 1 461 cm3
# 0 KM
# 23 800PLN
# 188 000 km
# Diesel
# Manualna
# 2015
# Dacia Duster
# 1 461 cm3
# 16 KM
# 62 000PLN
# 29 000 km
# Diesel
# Manualna
# 2021
#
# 999 cm3 •
# KM •
# 86 301PLN
# 1 km
# Benzyna+LPG
# Manualna
# 2023
# Dacia Logan MCV 0.9 TCE Prestige
# 898 cm3 •
# KM •
# 19 781PLN
# 169 517 km
# Benzyna
# Manualna
# 2013
# Dacia Dokker
# 1 461 cm3
# 5 KM
# 24 171PLN
# 146 383 km
# Diesel
# Manualna
# 2016
# Dacia Duster
# 999 cm3 •
#  KM •
# 59 900PLN
# 81 212 km
# Benzyna+LPG
# Manualna
# 2020
# Dacia Duster 1.0 TCe SL Celebration
# 999 cm3 •
# KM •
# 59 900PLN
# 45 000 km
# Benzyna+LPG
# Manualna
# 2020
# Dacia Duster
# 999 cm3 •
# KM •
# 96 800PLN
# 10 km
# Benzyna+LPG
# Manualna
# 2024
# Dacia Duster 1.6 SCe Laureate S&S
# 1 598 cm3
# 14 KM
# 56 900PLN
# 90 150 km
# Benzyna
# Manualna
# 2018
# Dacia Duster
# 1 598 cm3
# 14 KM
# 64 900PLN
# 47 200 km
# Benzyna
# Manualna
# 2019
# Dacia Duster
# 999 cm3 •
#  KM •
# 55 900PLN
# 98 100 km
# Benzyna+LPG
# Manualna
# 2021
# Dacia Duster 1.5 dCi SL Off-Road 4x4
# 1 461 cm3
# 10 KM
# 28 500PLN
# 180 000 km
# Diesel
# Manualna
# 2012
# Dacia Sandero Stepway TCe 90 Prestige
# 898 cm3 •
# KM •
# 29 900PLN
# 60 000 km
# Benzyna
# Manualna
# 2013
# Dacia Dokker 1.2 TCe Outdoor
# 1 197 cm3
# 15 KM
# 43 050PLN
# 118 000 km
# Benzyna+LPG
# Manualna
# 2018
# Dacia Sandero Stepway
# 999 cm3 •
#  KM •
# 27 900PLN
# 13 000 km
# Benzyna
# Manualna
# 2021
#
# 1 598 cm3
# 15 KM
# 52 900PLN
# 204 204 km
# Benzyna
# Manualna
# 2019
# Dacia Duster
# 999 cm3 •
# KM •
# 79 990PLN
# 8 097 km
# Benzyna+LPG
# Manualna
# 2023
# Dacia Sandero 1.2 16V 75 Ambiance
# 1 149 cm3
# 5 KM
# 9 900PLN
# 174 188 km
# Benzyna
# Manualna
# 2009
#
# 999 cm3 •
#  KM •
# 92 350PLN
# 1 km
# Benzyna
# Manualna
# 2023
# Dacia Logan Van
# 1 197 cm3
# 15 KM
# 15 500PLN
# 70 500 km
# Benzyna
# Manualna
# 2018
# Dacia Dokker 1.6 MPI 85 Ambiance
# 1 598 cm3
# 3 KM
# 28 900PLN
# 205 362 km
# Benzyna+LPG
# Manualna
# 2014
#
# 999 cm3 •
#  KM •
# 89 000PLN
# 1 km
# Benzyna+LPG
# Manualna
# 2023
# Dacia Lodgy dCi 110 Stepway
# 1 461 cm3
# 09 KM
# 20 999PLN
# 218 000 km
# Diesel
# Manualna
# 2016
# Dacia Duster 1.0 TCe Prestige
# 999 cm3 •
#  KM
# 71 000PLN
# 32 400 km
# Benzyna+LPG
# Manualna
# 2021
# Dacia Duster 1.6 SCe Laureate S&S
# 1 598 cm3
# 14 KM
# 55 200PLN
# 122 142 km
# Benzyna
# Manualna
# 2019
# Dacia Duster
# 1 461 cm3
# 15 KM
# 34 900PLN
# 33 908 km
# Diesel
# Manualna
# 2022
# Dacia Duster
# 1 332 cm3
# 30 KM
# 52 000PLN
# 70 554 km
# Benzyna
# Manualna
# 2019
# Dacia Sandero Stepway
# 1 461 cm3
# 0 KM
# 11 900PLN
# 183 000 km
# Diesel
# Manualna
# 2013
# Dacia Sandero 1.0 TCe Expression
# 999 cm3 •
# KM •
# 49 999PLN
# 85 000 km
# Benzyna
# Manualna
# 2021
# Dacia Duster 1.3 TCe SL Extreme 4WD
# 1 332 cm3
# 50 KM
# 95 000PLN
# 13 800 km
# Benzyna
# Manualna
# 2023
# Dacia Duster 1.5 dCi Laureate 4x4
# 1 461 cm3
# 10 KM
# 25 900PLN
# 211 000 km
# Diesel
# Manualna
# 2012
# Dacia Duster Blue dCi 115 4WD Expression
# 1 461 cm3
# 14 KM
# 59 700PLN
# 26 000 km
# Diesel
# Manualna
# 2022
# Dacia Sandero Stepway
# 1 461 cm3
# 0 KM
# 23 800PLN
# 188 000 km
# Diesel
# Manualna
# 2015
# Dacia Duster
# 1 461 cm3
# 16 KM
# 62 000PLN
# 29 000 km
# Diesel
# Manualna
# 2021
#
# 999 cm3 •
# KM •
# 86 301PLN
# 1 km
# Benzyna+LPG
# Manualna
# 2023
# Dacia Logan MCV 0.9 TCE Prestige
# 898 cm3 •
# KM •
# 19 781PLN
# 169 517 km
# Benzyna
# Manualna
# 2013
# Dacia Dokker
# 1 461 cm3
# 5 KM
# 24 171PLN
# 146 383 km
# Diesel
# Manualna
# 2016
# Dacia Duster
# 999 cm3 •
#  KM •
# 59 900PLN
# 81 212 km
# Benzyna+LPG
# Manualna
# 2020
# Dacia Duster 1.0 TCe SL Celebration
# 999 cm3 •
# KM •
# 59 900PLN
# 45 000 km
# Benzyna+LPG
# Manualna
# 2020
# Dacia Duster
# 999 cm3 •
# KM •
# 96 800PLN
# 10 km
# Benzyna+LPG
# Manualna
# 2024
# Dacia Duster 1.6 SCe Laureate S&S
# 1 598 cm3
# 14 KM
# 56 900PLN
# 90 150 km
# Benzyna
# Manualna
# 2018
# Dacia Duster
# 1 598 cm3
# 14 KM
# 64 900PLN
# 47 200 km
# Benzyna
# Manualna
# 2019
# Dacia Duster
# 999 cm3 •
#  KM •
# 55 900PLN
# 98 100 km
# Benzyna+LPG
# Manualna
# 2021
# Dacia Duster 1.5 dCi SL Off-Road 4x4
# 1 461 cm3
# 10 KM
# 28 500PLN
# 180 000 km
# Diesel
# Manualna
# 2012
# Dacia Sandero Stepway TCe 90 Prestige
# 898 cm3 •
# KM •
# 29 900PLN
# 60 000 km
# Benzyna
# Manualna
# 2013
# Dacia Dokker 1.2 TCe Outdoor
# 1 197 cm3
# 15 KM
# 43 050PLN
# 118 000 km
# Benzyna+LPG
# Manualna
# 2018
# Dacia Sandero Stepway
# 999 cm3 •
#  KM •
# 27 900PLN
# 13 000 km
# Benzyna
# Manualna
# 2021
#
# 1 598 cm3
# 15 KM
# 52 900PLN
# 204 204 km
# Benzyna
# Manualna
# 2019
# Dacia Duster
# 999 cm3 •
# KM •
# 79 990PLN
# 8 097 km
# Benzyna+LPG
# Manualna
# 2023
# Dacia Sandero 1.2 16V 75 Ambiance
# 1 149 cm3
# 5 KM
# 9 900PLN
# 174 188 km
# Benzyna
# Manualna
# 2009
#
# 999 cm3 •
#  KM •
# 92 350PLN
# 1 km
# Benzyna
# Manualna
# 2023
# Dacia Logan Van
# 1 197 cm3
# 15 KM
# 15 500PLN
# 70 500 km
# Benzyna
# Manualna
# 2018
# Dacia Dokker 1.6 MPI 85 Ambiance
# 1 598 cm3
# 3 KM
# 28 900PLN
# 205 362 km
# Benzyna+LPG
# Manualna
# 2014
#
# 999 cm3 •
#  KM •
# 89 000PLN
# 1 km
# Benzyna+LPG
# Manualna
# 2023
# Dacia Lodgy dCi 110 Stepway
# 1 461 cm3
# 09 KM
# 20 999PLN
# 218 000 km
# Diesel
# Manualna
# 2016
# Dacia Duster 1.0 TCe Prestige
# 999 cm3 •
#  KM
# 71 000PLN
# 32 400 km
# Benzyna+LPG
# Manualna
# 2021
# Dacia Duster 1.6 SCe Laureate S&S
# 1 598 cm3
# 14 KM
# 55 200PLN
# 122 142 km
# Benzyna
# Manualna
# 2019
# Dacia Duster
# 1 461 cm3
# 15 KM
# 34 900PLN
# 33 908 km
# Diesel
# Manualna
# 2022
# Dacia Duster
# 1 332 cm3
# 30 KM
# 52 000PLN
# 70 554 km
# Benzyna
# Manualna
# 2019
# Dacia Sandero Stepway
# 1 461 cm3
# 0 KM
# 11 900PLN
# 183 000 km
# Diesel
# Manualna
# 2013
# Dacia Sandero 1.0 TCe Expression
# 999 cm3 •
# KM •
# 49 999PLN
# 85 000 km
# Benzyna
# Manualna
# 2021
# Dacia Duster 1.3 TCe SL Extreme 4WD
# 1 332 cm3
# 50 KM
# 95 000PLN
# 13 800 km
# Benzyna
# Manualna
# 2023
# Dacia Duster 1.5 dCi Laureate 4x4
# 1 461 cm3
# 10 KM
# 25 900PLN
# 211 000 km
# Diesel
# Manualna
# 2012
# Dacia Duster Blue dCi 115 4WD Expression
# 1 461 cm3
# 14 KM
# 59 700PLN
# 26 000 km
# Diesel
# Manualna
# 2022
# Dacia Sandero Stepway
# 1 461 cm3
# 0 KM
# 23 800PLN
# 188 000 km
# Diesel
# Manualna
# 2015
# Dacia Duster
# 1 461 cm3
# 16 KM
# 62 000PLN
# 29 000 km
# Diesel
# Manualna
# 2021
#
# 999 cm3 •
# KM •
# 86 301PLN
# 1 km
# Benzyna+LPG
# Manualna
# 2023
# Dacia Logan MCV 0.9 TCE Prestige
# 898 cm3 •
# KM •
# 19 781PLN
# 169 517 km
# Benzyna
# Manualna
# 2013
# Dacia Dokker
# 1 461 cm3
# 5 KM
# 24 171PLN
# 146 383 km
# Diesel
# Manualna
# 2016
# Dacia Duster
# 999 cm3 •
#  KM •
# 59 900PLN
# 81 212 km
# Benzyna+LPG
# Manualna
# 2020
# Dacia Duster 1.0 TCe SL Celebration
# 999 cm3 •
# KM •
# 59 900PLN
# 45 000 km
# Benzyna+LPG
# Manualna
# 2020
# Dacia Duster
# 999 cm3 •
# KM •
# 96 800PLN
# 10 km
# Benzyna+LPG
# Manualna
# 2024
# Dacia Duster 1.6 SCe Laureate S&S
# 1 598 cm3
# 14 KM
# 56 900PLN
# 90 150 km
# Benzyna
# Manualna
# 2018
# Dacia Duster
# 1 598 cm3
# 14 KM
# 64 900PLN
# 47 200 km
# Benzyna
# Manualna
# 2019
# Dacia Duster
# 999 cm3 •
#  KM •
# 55 900PLN
# 98 100 km
# Benzyna+LPG
# Manualna
# 2021
# Dacia Duster 1.5 dCi SL Off-Road 4x4
# 1 461 cm3
# 10 KM
# 28 500PLN
# 180 000 km
# Diesel
# Manualna
# 2012
# Dacia Sandero Stepway TCe 90 Prestige
# 898 cm3 •
# KM •
# 29 900PLN
# 60 000 km
# Benzyna
# Manualna
# 2013
# Dacia Dokker 1.2 TCe Outdoor
# 1 197 cm3
# 15 KM
# 43 050PLN
# 118 000 km
# Benzyna+LPG
# Manualna
# 2018
# Dacia Sandero Stepway
# 999 cm3 •
#  KM •
# 27 900PLN
# 13 000 km
# Benzyna
# Manualna
# 2021
#
# 1 598 cm3
# 15 KM
# 52 900PLN
# 204 204 km
# Benzyna
# Manualna
# 2019
# Dacia Duster
# 999 cm3 •
# KM •
# 79 990PLN
# 8 097 km
# Benzyna+LPG
# Manualna
# 2023
# Dacia Sandero 1.2 16V 75 Ambiance
# 1 149 cm3
# 5 KM
# 9 900PLN
# 174 188 km
# Benzyna
# Manualna
# 2009
#
# 999 cm3 •
#  KM •
# 92 350PLN
# 1 km
# Benzyna
# Manualna
# 2023
# Dacia Logan Van
# 1 197 cm3
# 15 KM
# 15 500PLN
# 70 500 km
# Benzyna
# Manualna
# 2018
# Dacia Dokker 1.6 MPI 85 Ambiance
# 1 598 cm3
# 3 KM
# 28 900PLN
# 205 362 km
# Benzyna+LPG
# Manualna
# 2014
#
# 999 cm3 •
#  KM •
# 89 000PLN
# 1 km
# Benzyna+LPG
# Manualna
# 2023
# Dacia Lodgy dCi 110 Stepway
# 1 461 cm3
# 09 KM
# 20 999PLN
# 218 000 km
# Diesel
# Manualna
# 2016
# Dacia Duster 1.0 TCe Prestige
# 999 cm3 •
#  KM
# 71 000PLN
# 32 400 km
# Benzyna+LPG
# Manualna
# 2021
# Dacia Duster 1.6 SCe Laureate S&S
# 1 598 cm3
# 14 KM
# 55 200PLN
# 122 142 km
# Benzyna
# Manualna
# 2019
# Dacia Duster
# 1 461 cm3
# 15 KM
# 34 900PLN
# 33 908 km
# Diesel
# Manualna
# 2022
# Dacia Duster
# 1 332 cm3
# 30 KM
# 52 000PLN
# 70 554 km
# Benzyna
# Manualna
# 2019
# Dacia Sandero Stepway
# 1 461 cm3
# 0 KM
# 11 900PLN
# 183 000 km
# Diesel
# Manualna
# 2013
# Dacia Sandero 1.0 TCe Expression
# 999 cm3 •
# KM •
# 49 999PLN
# 85 000 km
# Benzyna
# Manualna
# 2021
# Dacia Duster 1.3 TCe SL Extreme 4WD
# 1 332 cm3
# 50 KM
# 95 000PLN
# 13 800 km
# Benzyna
# Manualna
# 2023
# Dacia Duster 1.5 dCi Laureate 4x4
# 1 461 cm3
# 10 KM
# 25 900PLN
# 211 000 km
# Diesel
# Manualna
# 2012
# Dacia Duster Blue dCi 115 4WD Expression
# 1 461 cm3
# 14 KM
# 59 700PLN
# 26 000 km
# Diesel
# Manualna
# 2022
# Dacia Sandero Stepway
# 1 461 cm3
# 0 KM
# 23 800PLN
# 188 000 km
# Diesel
# Manualna
# 2015
# Dacia Duster
# 1 461 cm3
# 16 KM
# 62 000PLN
# 29 000 km
# Diesel
# Manualna
# 2021
#
# 999 cm3 •
# KM •
# 86 301PLN
# 1 km
# Benzyna+LPG
# Manualna
# 2023
# Dacia Logan MCV 0.9 TCE Prestige
# 898 cm3 •
# KM •
# 19 781PLN
# 169 517 km
# Benzyna
# Manualna
# 2013
# Dacia Dokker
# 1 461 cm3
# 5 KM
# 24 171PLN
# 146 383 km
# Diesel
# Manualna
# 2016
# Dacia Duster
# 999 cm3 •
#  KM •
# 59 900PLN
# 81 212 km
# Benzyna+LPG
# Manualna
# 2020
# Dacia Duster 1.0 TCe SL Celebration
# 999 cm3 •
# KM •
# 59 900PLN
# 45 000 km
# Benzyna+LPG
# Manualna
# 2020
# Dacia Duster
# 999 cm3 •
# KM •
# 96 800PLN
# 10 km
# Benzyna+LPG
# Manualna
# 2024
# Dacia Duster 1.6 SCe Laureate S&S
# 1 598 cm3
# 14 KM
# 56 900PLN
# 90 150 km
# Benzyna
# Manualna
# 2018
# Dacia Duster
# 1 598 cm3
# 14 KM
# 64 900PLN
# 47 200 km
# Benzyna
# Manualna
# 2019
# Dacia Duster
# 999 cm3 •
#  KM •
# 55 900PLN
# 98 100 km
# Benzyna+LPG
# Manualna
# 2021
# Dacia Duster 1.5 dCi SL Off-Road 4x4
# 1 461 cm3
# 10 KM
# 28 500PLN
# 180 000 km
# Diesel
# Manualna
# 2012
# Dacia Sandero Stepway TCe 90 Prestige
# 898 cm3 •
# KM •
# 29 900PLN
# 60 000 km
# Benzyna
# Manualna
# 2013
# Dacia Dokker 1.2 TCe Outdoor
# 1 197 cm3
# 15 KM
# 43 050PLN
# 118 000 km
# Benzyna+LPG
# Manualna
# 2018
# Dacia Sandero Stepway
# 999 cm3 •
#  KM •
# 27 900PLN
# 13 000 km
# Benzyna
# Manualna
# 2021
#
# 1 598 cm3
# 15 KM
# 52 900PLN
# 204 204 km
# Benzyna
# Manualna
# 2019
# Dacia Duster
# 999 cm3 •
# KM •
# 79 990PLN
# 8 097 km
# Benzyna+LPG
# Manualna
# 2023
# Dacia Sandero 1.2 16V 75 Ambiance
# 1 149 cm3
# 5 KM
# 9 900PLN
# 174 188 km
# Benzyna
# Manualna
# 2009
#
# 999 cm3 •
#  KM •
# 92 350PLN
# 1 km
# Benzyna
# Manualna
# 2023
# Dacia Logan Van
# 1 197 cm3
# 15 KM
# 15 500PLN
# 70 500 km
# Benzyna
# Manualna
# 2018
# Dacia Dokker 1.6 MPI 85 Ambiance
# 1 598 cm3
# 3 KM
# 28 900PLN
# 205 362 km
# Benzyna+LPG
# Manualna
# 2014
#
# 999 cm3 •
#  KM •
# 89 000PLN
# 1 km
# Benzyna+LPG
# Manualna
# 2023
# Dacia Lodgy dCi 110 Stepway
# 1 461 cm3
# 09 KM
# 20 999PLN
# 218 000 km
# Diesel
# Manualna
# 2016
# Dacia Duster 1.0 TCe Prestige
# 999 cm3 •
#  KM
# 71 000PLN
# 32 400 km
# Benzyna+LPG
# Manualna
# 2021
# Dacia Duster 1.6 SCe Laureate S&S
# 1 598 cm3
# 14 KM
# 55 200PLN
# 122 142 km
# Benzyna
# Manualna
# 2019
# Dacia Duster
# 1 461 cm3
# 15 KM
# 34 900PLN
# 33 908 km
# Diesel
# Manualna
# 2022
# Dacia Duster
# 1 332 cm3
# 30 KM
# 52 000PLN
# 70 554 km
# Benzyna
# Manualna
# 2019
# Dacia Sandero Stepway
# 1 461 cm3
# 0 KM
# 11 900PLN
# 183 000 km
# Diesel
# Manualna
# 2013
# Dacia Sandero 1.0 TCe Expression
# 999 cm3 •
# KM •
# 49 999PLN
# 85 000 km
# Benzyna
# Manualna
# 2021
# Dacia Duster 1.3 TCe SL Extreme 4WD
# 1 332 cm3
# 50 KM
# 95 000PLN
# 13 800 km
# Benzyna
# Manualna
# 2023
# Dacia Duster 1.5 dCi Laureate 4x4
# 1 461 cm3
# 10 KM
# 25 900PLN
# 211 000 km
# Diesel
# Manualna
# 2012
# Dacia Duster Blue dCi 115 4WD Expression
# 1 461 cm3
# 14 KM
# 59 700PLN
# 26 000 km
# Diesel
# Manualna
# 2022
# Dacia Sandero Stepway
# 1 461 cm3
# 0 KM
# 23 800PLN
# 188 000 km
# Diesel
# Manualna
# 2015
# Dacia Duster
# 1 461 cm3
# 16 KM
# 62 000PLN
# 29 000 km
# Diesel
# Manualna
# 2021
#
# 999 cm3 •
# KM •
# 86 301PLN
# 1 km
# Benzyna+LPG
# Manualna
# 2023
# Dacia Logan MCV 0.9 TCE Prestige
# 898 cm3 •
# KM •
# 19 781PLN
# 169 517 km
# Benzyna
# Manualna
# 2013
# Dacia Dokker
# 1 461 cm3
# 5 KM
# 24 171PLN
# 146 383 km
# Diesel
# Manualna
# 2016
# Dacia Duster
# 999 cm3 •
#  KM •
# 59 900PLN
# 81 212 km
# Benzyna+LPG
# Manualna
# 2020
# Dacia Duster 1.0 TCe SL Celebration
# 999 cm3 •
# KM •
# 59 900PLN
# 45 000 km
# Benzyna+LPG
# Manualna
# 2020
# Dacia Duster
# 999 cm3 •
# KM •
# 96 800PLN
# 10 km
# Benzyna+LPG
# Manualna
# 2024
# Dacia Duster 1.6 SCe Laureate S&S
# 1 598 cm3
# 14 KM
# 56 900PLN
# 90 150 km
# Benzyna
# Manualna
# 2018
# Dacia Duster
# 1 598 cm3
# 14 KM
# 64 900PLN
# 47 200 km
# Benzyna
# Manualna
# 2019
# Dacia Duster
# 999 cm3 •
#  KM •
# 55 900PLN
# 98 100 km
# Benzyna+LPG
# Manualna
# 2021
# Dacia Duster 1.5 dCi SL Off-Road 4x4
# 1 461 cm3
# 10 KM
# 28 500PLN
# 180 000 km
# Diesel
# Manualna
# 2012
# Dacia Sandero Stepway TCe 90 Prestige
# 898 cm3 •
# KM •
# 29 900PLN
# 60 000 km
# Benzyna
# Manualna
# 2013
# Dacia Dokker 1.2 TCe Outdoor
# 1 197 cm3
# 15 KM
# 43 050PLN
# 118 000 km
# Benzyna+LPG
# Manualna
# 2018
# Dacia Sandero Stepway
# 999 cm3 •
#  KM •
# 27 900PLN
# 13 000 km
# Benzyna
# Manualna
# 2021
#
# 1 598 cm3
# 15 KM
# 52 900PLN
# 204 204 km
# Benzyna
# Manualna
# 2019
# Dacia Duster
# 999 cm3 •
# KM •
# 79 990PLN
# 8 097 km
# Benzyna+LPG
# Manualna
# 2023
# Dacia Sandero 1.2 16V 75 Ambiance
# 1 149 cm3
# 5 KM
# 9 900PLN
# 174 188 km
# Benzyna
# Manualna
# 2009
#
# 999 cm3 •
#  KM •
# 92 350PLN
# 1 km
# Benzyna
# Manualna
# 2023
# Dacia Logan Van
# 1 197 cm3
# 15 KM
# 15 500PLN
# 70 500 km
# Benzyna
# Manualna
# 2018
# Dacia Dokker 1.6 MPI 85 Ambiance
# 1 598 cm3
# 3 KM
# 28 900PLN
# 205 362 km
# Benzyna+LPG
# Manualna
# 2014
#
# 999 cm3 •
#  KM •
# 89 000PLN
# 1 km
# Benzyna+LPG
# Manualna
# 2023
# Dacia Lodgy dCi 110 Stepway
# 1 461 cm3
# 09 KM
# 20 999PLN
# 218 000 km
# Diesel
# Manualna
# 2016
# Dacia Duster 1.0 TCe Prestige
# 999 cm3 •
#  KM
# 71 000PLN
# 32 400 km
# Benzyna+LPG
# Manualna
# 2021
# Dacia Duster 1.6 SCe Laureate S&S
# 1 598 cm3
# 14 KM
# 55 200PLN
# 122 142 km
# Benzyna
# Manualna
# 2019
# Dacia Duster
# 1 461 cm3
# 15 KM
# 34 900PLN
# 33 908 km
# Diesel
# Manualna
# 2022
# Dacia Duster
# 1 332 cm3
# 30 KM
# 52 000PLN
# 70 554 km
# Benzyna
# Manualna
# 2019
# Dacia Sandero Stepway
# 1 461 cm3
# 0 KM
# 11 900PLN
# 183 000 km
# Diesel
# Manualna
# 2013
# Dacia Sandero 1.0 TCe Expression
# 999 cm3 •
# KM •
# 49 999PLN
# 85 000 km
# Benzyna
# Manualna
# 2021
# Dacia Duster 1.3 TCe SL Extreme 4WD
# 1 332 cm3
# 50 KM
# 95 000PLN
# 13 800 km
# Benzyna
# Manualna
# 2023
# Dacia Duster 1.5 dCi Laureate 4x4
# 1 461 cm3
# 10 KM
# 25 900PLN
# 211 000 km
# Diesel
# Manualna
# 2012
# Dacia Duster Blue dCi 115 4WD Expression
# 1 461 cm3
# 14 KM
# 59 700PLN
# 26 000 km
# Diesel
# Manualna
# 2022
# Dacia Sandero Stepway
# 1 461 cm3
# 0 KM
# 23 800PLN
# 188 000 km
# Diesel
# Manualna
# 2015
# Dacia Duster
# 1 461 cm3
# 16 KM
# 62 000PLN
# 29 000 km
# Diesel
# Manualna
# 2021
#
# 999 cm3 •
# KM •
# 86 301PLN
# 1 km
# Benzyna+LPG
# Manualna
# 2023
# Dacia Logan MCV 0.9 TCE Prestige
# 898 cm3 •
# KM •
# 19 781PLN
# 169 517 km
# Benzyna
# Manualna
# 2013
# Dacia Dokker
# 1 461 cm3
# 5 KM
# 24 171PLN
# 146 383 km
# Diesel
# Manualna
# 2016
# Dacia Duster
# 999 cm3 •
#  KM •
# 59 900PLN
# 81 212 km
# Benzyna+LPG
# Manualna
# 2020
# Dacia Duster 1.0 TCe SL Celebration
# 999 cm3 •
# KM •
# 59 900PLN
# 45 000 km
# Benzyna+LPG
# Manualna
# 2020
# Dacia Duster
# 999 cm3 •
# KM •
# 96 800PLN
# 10 km
# Benzyna+LPG
# Manualna
# 2024
# Dacia Duster 1.6 SCe Laureate S&S
# 1 598 cm3
# 14 KM
# 56 900PLN
# 90 150 km
# Benzyna
# Manualna
# 2018
# Dacia Duster
# 1 598 cm3
# 14 KM
# 64 900PLN
# 47 200 km
# Benzyna
# Manualna
# 2019
# Dacia Duster
# 999 cm3 •
#  KM •
# 55 900PLN
# 98 100 km
# Benzyna+LPG
# Manualna
# 2021
# Dacia Duster 1.5 dCi SL Off-Road 4x4
# 1 461 cm3
# 10 KM
# 28 500PLN
# 180 000 km
# Diesel
# Manualna
# 2012
# Dacia Sandero Stepway TCe 90 Prestige
# 898 cm3 •
# KM •
# 29 900PLN
# 60 000 km
# Benzyna
# Manualna
# 2013
# Dacia Dokker 1.2 TCe Outdoor
# 1 197 cm3
# 15 KM
# 43 050PLN
# 118 000 km
# Benzyna+LPG
# Manualna
# 2018
# Dacia Sandero Stepway
# 999 cm3 •
#  KM •
# 27 900PLN
# 13 000 km
# Benzyna
# Manualna
# 2021
#
# 1 598 cm3
# 15 KM
# 52 900PLN
# 204 204 km
# Benzyna
# Manualna
# 2019
# Dacia Duster
# 999 cm3 •
# KM •
# 79 990PLN
# 8 097 km
# Benzyna+LPG
# Manualna
# 2023
# Dacia Sandero 1.2 16V 75 Ambiance
# 1 149 cm3
# 5 KM
# 9 900PLN
# 174 188 km
# Benzyna
# Manualna
# 2009
#
# 999 cm3 •
#  KM •
# 92 350PLN
# 1 km
# Benzyna
# Manualna
# 2023
# Dacia Logan Van
# 1 197 cm3
# 15 KM
# 15 500PLN
# 70 500 km
# Benzyna
# Manualna
# 2018
# Dacia Dokker 1.6 MPI 85 Ambiance
# 1 598 cm3
# 3 KM
# 28 900PLN
# 205 362 km
# Benzyna+LPG
# Manualna
# 2014
#
# 999 cm3 •
#  KM •
# 89 000PLN
# 1 km
# Benzyna+LPG
# Manualna
# 2023
# Dacia Lodgy dCi 110 Stepway
# 1 461 cm3
# 09 KM
# 20 999PLN
# 218 000 km
# Diesel
# Manualna
# 2016
# Dacia Duster 1.0 TCe Prestige
# 999 cm3 •
#  KM
# 71 000PLN
# 32 400 km
# Benzyna+LPG
# Manualna
# 2021
# Dacia Duster 1.6 SCe Laureate S&S
# 1 598 cm3
# 14 KM
# 55 200PLN
# 122 142 km
# Benzyna
# Manualna
# 2019
# Dacia Duster
# 1 461 cm3
# 15 KM
# 34 900PLN
# 33 908 km
# Diesel
# Manualna
# 2022
# Dacia Duster
# 1 332 cm3
# 30 KM
# 52 000PLN
# 70 554 km
# Benzyna
# Manualna
# 2019
# Dacia Sandero Stepway
# 1 461 cm3
# 0 KM
# 11 900PLN
# 183 000 km
# Diesel
# Manualna
# 2013
# Dacia Sandero 1.0 TCe Expression
# 999 cm3 •
# KM •
# 49 999PLN
# 85 000 km
# Benzyna
# Manualna
# 2021
# Dacia Duster 1.3 TCe SL Extreme 4WD
# 1 332 cm3
# 50 KM
# 95 000PLN
# 13 800 km
# Benzyna
# Manualna
# 2023
# Dacia Duster 1.5 dCi Laureate 4x4
# 1 461 cm3
# 10 KM
# 25 900PLN
# 211 000 km
# Diesel
# Manualna
# 2012
# Dacia Duster Blue dCi 115 4WD Expression
# 1 461 cm3
# 14 KM
# 59 700PLN
# 26 000 km
# Diesel
# Manualna
# 2022
# Dacia Sandero Stepway
# 1 461 cm3
# 0 KM
# 23 800PLN
# 188 000 km
# Diesel
# Manualna
# 2015
# Dacia Duster
# 1 461 cm3
# 16 KM
# 62 000PLN
# 29 000 km
# Diesel
# Manualna
# 2021
#
# 999 cm3 •
# KM •
# 86 301PLN
# 1 km
# Benzyna+LPG
# Manualna
# 2023
# Dacia Logan MCV 0.9 TCE Prestige
# 898 cm3 •
# KM •
# 19 781PLN
# 169 517 km
# Benzyna
# Manualna
# 2013
# Dacia Dokker
# 1 461 cm3
# 5 KM
# 24 171PLN
# 146 383 km
# Diesel
# Manualna
# 2016
# Dacia Duster
# 999 cm3 •
#  KM •
# 59 900PLN
# 81 212 km
# Benzyna+LPG
# Manualna
# 2020
# Dacia Duster 1.0 TCe SL Celebration
# 999 cm3 •
# KM •
# 59 900PLN
# 45 000 km
# Benzyna+LPG
# Manualna
# 2020
# Dacia Duster
# 999 cm3 •
# KM •
# 96 800PLN
# 10 km
# Benzyna+LPG
# Manualna
# 2024
# Dacia Duster 1.6 SCe Laureate S&S
# 1 598 cm3
# 14 KM
# 56 900PLN
# 90 150 km
# Benzyna
# Manualna
# 2018
# Dacia Duster
# 1 598 cm3
# 14 KM
# 64 900PLN
# 47 200 km
# Benzyna
# Manualna
# 2019
# Dacia Duster
# 999 cm3 •
#  KM •
# 55 900PLN
# 98 100 km
# Benzyna+LPG
# Manualna
# 2021
# Dacia Duster 1.5 dCi SL Off-Road 4x4
# 1 461 cm3
# 10 KM
# 28 500PLN
# 180 000 km
# Diesel
# Manualna
# 2012
# Dacia Sandero Stepway TCe 90 Prestige
# 898 cm3 •
# KM •
# 29 900PLN
# 60 000 km
# Benzyna
# Manualna
# 2013
# Dacia Dokker 1.2 TCe Outdoor
# 1 197 cm3
# 15 KM
# 43 050PLN
# 118 000 km
# Benzyna+LPG
# Manualna
# 2018
# Dacia Sandero Stepway
# 999 cm3 •
#  KM •
# 27 900PLN
# 13 000 km
# Benzyna
# Manualna
# 2021
#
# 1 598 cm3
# 15 KM
# 52 900PLN
# 204 204 km
# Benzyna
# Manualna
# 2019
# Dacia Duster
# 999 cm3 •
# KM •
# 79 990PLN
# 8 097 km
# Benzyna+LPG
# Manualna
# 2023
# Dacia Sandero 1.2 16V 75 Ambiance
# 1 149 cm3
# 5 KM
# 9 900PLN
# 174 188 km
# Benzyna
# Manualna
# 2009
#
# 999 cm3 •
#  KM •
# 92 350PLN
# 1 km
# Benzyna
# Manualna
# 2023
# Dacia Logan Van
# 1 197 cm3
# 15 KM
# 15 500PLN
# 70 500 km
# Benzyna
# Manualna
# 2018
# Dacia Dokker 1.6 MPI 85 Ambiance
# 1 598 cm3
# 3 KM
# 28 900PLN
# 205 362 km
# Benzyna+LPG
# Manualna
# 2014
#
# 999 cm3 •
#  KM •
# 89 000PLN
# 1 km
# Benzyna+LPG
# Manualna
# 2023
# Mercedes-Benz GL 400 4Matic 7G-TRONIC
# 2 996 cm3
# 33 KM
# 135 000PLN
# 85 000 km
# Benzyna
# Automatyczna
# 2015
# Mercedes-Benz EQS 580 4-Matic AMG Line
# 523 KM •
# 580AM
# 553 500PLN
# 20 500 km
# Elektryczny
# Automatyczna
# 2022
# Mercedes-Benz Klasa C 300 7G-TRONIC Avantgarde
# 1 991 cm3
# 45 KM
# 98 500PLN
# 134 500 km
# Benzyna
# Automatyczna
# 2016
# Mercedes-Benz Klasa C 180 CGI BlueEff Avantgarde
# 1 595 cm3
# 56 KM
# 71 000PLN
# 45 500 km
# Benzyna
# Manualna
# 2014
# Mercedes-Benz Klasa A 180 d 7G-DCT Edition 2020
# 1 461 cm3
# 16 KM
# 69 000PLN
# 107 000 km
# Diesel
# Automatyczna
# 2021
# Mercedes-Benz CLA 220 4-Matic AMG Line
# 1 991 cm3
# 84 KM
# 126 284PLN
# 118 000 km
# Benzyna
# Automatyczna
# 2017
# Mercedes-Benz Klasa B 250 (BlueEFFICIENCY) 7G-DCT
# 1 991 cm3
# 11 KM
# 44 900PLN
# 96 992 km
# Benzyna
# Automatyczna
# 2013
# Mercedes-Benz GLC 250 4-Matic
# 1 991 cm3
# 11 KM
# 157 900PLN
# 53 000 km
# Benzyna
# Automatyczna
# 2018
# Mercedes-Benz GLB 200 AMG Line 7G-DCT
# 1 332 cm3
# 63 KM
# 159 500PLN
# 96 000 km
# Benzyna
# Automatyczna
# 2020
# Mercedes-Benz SL 500
# 4 973 cm3
# 20 KM
# 95 000PLN
# 175 000 km
# Benzyna
# Automatyczna
# 1998
# Mercedes-Benz Klasa C 300 7G-TRONIC
# 1 991 cm3
# 45 KM
# 135 000PLN
# 87 052 km
# Benzyna
# Automatyczna
# 2016
# Mercedes-Benz ML 420 CDI 4-Matic
# 3 996 cm3
# 06 KM
# 45 400PLN
# 251 400 km
# Diesel
# Automatyczna
# 2007
# Mercedes-Benz Klasa E 200 Coupe 4-Matic 9G-TRONIC
# 1 991 cm3
# 97 KM
# 220 000PLN
# 82 000 km
# Benzyna
# Automatyczna
# 2020
# Mercedes-Benz GLB 250 8G-DCT AMG Line
# 1 991 cm3
# 24 KM
# 179 000PLN
# 24 835 km
# Benzyna
# Automatyczna
# 2021
# Mercedes-Benz Klasa S 450 Coupe 4-Matic 9G-TRONIC
# 2 996 cm3
# 67 KM
# 380 000PLN
# 50 000 km
# Benzyna
# Automatyczna
# 2020
# Mercedes-Benz Klasa A 160 d
# 1 461 cm3
# 0 KM
# 54 500PLN
# 101 300 km
# Diesel
# Manualna
# 2016
# Mercedes-Benz Klasa B
# 1 461 cm3
# 09 KM
# 65 000PLN
# 179 297 km
# Diesel
# Automatyczna
# 2016
# Mercedes-Benz Klasa E 200
# 1 991 cm3
# 97 KM
# 163 000PLN
# 40 650 km
# Benzyna
# Automatyczna
# 2020
# Mercedes-Benz Klasa A
# 1 498 cm3
# 5 KM
# 19 900PLN
# 160 000 km
# Benzyna
# Manualna
# 2010
# Mercedes-Benz GLC 220 d 4-Matic
# 2 143 cm3
# 70 KM
# 149 888PLN
# 111 500 km
# Diesel
# Automatyczna
# 2018
# Mercedes-Benz Klasa C
# 1 796 cm3
# 84 KM
# 49 700PLN
# 182 000 km
# Benzyna
# Automatyczna
# 2011
# Mercedes-Benz CLA 220 4-Matic
# 1 991 cm3
# 84 KM
# 129 500PLN
# 58 000 km
# Benzyna
# Automatyczna
# 2018
#
# 1 461 cm3
# 09 KM
# 95 900PLN
# 135 000 km
# Diesel
# Automatyczna
# 2017
# Mercedes-Benz Klasa C 200 T CDI DPF Automatik BlueEFFICIENCY Avantgarde
# 2 143 cm3
# 36 KM
# 31 500PLN
# 280 000 km
# Diesel
# Automatyczna
# 2011
# Mercedes-Benz Klasa A AMG 45 4-Matic
# 1 991 cm3
# 81 KM
# 149 900PLN
# 67 164 km
# Benzyna
# Automatyczna
# 2016
# Mercedes-Benz Klasa C 250 (BlueTEC) d 4-Matic 7G-TRONIC
# 2 143 cm3
# 04 KM
# 70 000PLN
# 192 000 km
# Diesel
# Automatyczna
# 2014
# Mercedes-Benz ML
# 2 987 cm3
# 58 KM
# 92 000PLN
# 245 000 km
# Diesel
# Automatyczna
# 2014
# Mercedes-Benz Klasa C 180 9G-TRONIC
# 1 595 cm3
# 56 KM
# 98 000PLN
# 94 000 km
# Benzyna
# Automatyczna
# 2018
# Mercedes-Benz Klasa E 220 d 4-Matic 9G-TRONIC
# 1 950 cm3
# 95 KM
# 139 900PLN
# 178 000 km
# Diesel
# Automatyczna
# 2017
# Mercedes-Benz Klasa S 580 4Matic L 9G-TRONIC
# 3 982 cm3
# 03 KM
# 570 000PLN
# 7 700 km
# Benzyna
# Automatyczna
# 2021
# Mercedes-Benz Klasa C 180 T BlueEFFICIENCY
# 1 796 cm3
# 56 KM
# 37 900PLN
# 136 002 km
# Benzyna
# Manualna
# 2010
# Mercedes-Benz Klasa C AMG 63
# 3 982 cm3
# 76 KM
# 199 900PLN
# 48 700 km
# Benzyna
# Automatyczna
# 2015
# Mercedes-Benz GL 400 4Matic 7G-TRONIC
# 2 996 cm3
# 33 KM
# 135 000PLN
# 85 000 km
# Benzyna
# Automatyczna
# 2015
# Mercedes-Benz EQS 580 4-Matic AMG Line
# 523 KM •
# 580AM
# 553 500PLN
# 20 500 km
# Elektryczny
# Automatyczna
# 2022
# Mercedes-Benz Klasa C 300 7G-TRONIC Avantgarde
# 1 991 cm3
# 45 KM
# 98 500PLN
# 134 500 km
# Benzyna
# Automatyczna
# 2016
# Mercedes-Benz Klasa C 180 CGI BlueEff Avantgarde
# 1 595 cm3
# 56 KM
# 71 000PLN
# 45 500 km
# Benzyna
# Manualna
# 2014
# Mercedes-Benz Klasa A 180 d 7G-DCT Edition 2020
# 1 461 cm3
# 16 KM
# 69 000PLN
# 107 000 km
# Diesel
# Automatyczna
# 2021
# Mercedes-Benz CLA 220 4-Matic AMG Line
# 1 991 cm3
# 84 KM
# 126 284PLN
# 118 000 km
# Benzyna
# Automatyczna
# 2017
# Mercedes-Benz Klasa B 250 (BlueEFFICIENCY) 7G-DCT
# 1 991 cm3
# 11 KM
# 44 900PLN
# 96 992 km
# Benzyna
# Automatyczna
# 2013
# Mercedes-Benz GLC 250 4-Matic
# 1 991 cm3
# 11 KM
# 157 900PLN
# 53 000 km
# Benzyna
# Automatyczna
# 2018
# Mercedes-Benz GLB 200 AMG Line 7G-DCT
# 1 332 cm3
# 63 KM
# 159 500PLN
# 96 000 km
# Benzyna
# Automatyczna
# 2020
# Mercedes-Benz SL 500
# 4 973 cm3
# 20 KM
# 95 000PLN
# 175 000 km
# Benzyna
# Automatyczna
# 1998
# Mercedes-Benz Klasa C 300 7G-TRONIC
# 1 991 cm3
# 45 KM
# 135 000PLN
# 87 052 km
# Benzyna
# Automatyczna
# 2016
# Mercedes-Benz ML 420 CDI 4-Matic
# 3 996 cm3
# 06 KM
# 45 400PLN
# 251 400 km
# Diesel
# Automatyczna
# 2007
# Mercedes-Benz Klasa E 200 Coupe 4-Matic 9G-TRONIC
# 1 991 cm3
# 97 KM
# 220 000PLN
# 82 000 km
# Benzyna
# Automatyczna
# 2020
# Mercedes-Benz GLB 250 8G-DCT AMG Line
# 1 991 cm3
# 24 KM
# 179 000PLN
# 24 835 km
# Benzyna
# Automatyczna
# 2021
# Mercedes-Benz Klasa S 450 Coupe 4-Matic 9G-TRONIC
# 2 996 cm3
# 67 KM
# 380 000PLN
# 50 000 km
# Benzyna
# Automatyczna
# 2020
# Mercedes-Benz Klasa A 160 d
# 1 461 cm3
# 0 KM
# 54 500PLN
# 101 300 km
# Diesel
# Manualna
# 2016
# Mercedes-Benz Klasa B
# 1 461 cm3
# 09 KM
# 65 000PLN
# 179 297 km
# Diesel
# Automatyczna
# 2016
# Mercedes-Benz Klasa E 200
# 1 991 cm3
# 97 KM
# 163 000PLN
# 40 650 km
# Benzyna
# Automatyczna
# 2020
# Mercedes-Benz Klasa A
# 1 498 cm3
# 5 KM
# 19 900PLN
# 160 000 km
# Benzyna
# Manualna
# 2010
# Mercedes-Benz GLC 220 d 4-Matic
# 2 143 cm3
# 70 KM
# 149 888PLN
# 111 500 km
# Diesel
# Automatyczna
# 2018
# Mercedes-Benz Klasa C
# 1 796 cm3
# 84 KM
# 49 700PLN
# 182 000 km
# Benzyna
# Automatyczna
# 2011
# Mercedes-Benz CLA 220 4-Matic
# 1 991 cm3
# 84 KM
# 129 500PLN
# 58 000 km
# Benzyna
# Automatyczna
# 2018
#
# 1 461 cm3
# 09 KM
# 95 900PLN
# 135 000 km
# Diesel
# Automatyczna
# 2017
# Mercedes-Benz Klasa C 200 T CDI DPF Automatik BlueEFFICIENCY Avantgarde
# 2 143 cm3
# 36 KM
# 31 500PLN
# 280 000 km
# Diesel
# Automatyczna
# 2011
# Mercedes-Benz Klasa A AMG 45 4-Matic
# 1 991 cm3
# 81 KM
# 149 900PLN
# 67 164 km
# Benzyna
# Automatyczna
# 2016
# Mercedes-Benz Klasa C 250 (BlueTEC) d 4-Matic 7G-TRONIC
# 2 143 cm3
# 04 KM
# 70 000PLN
# 192 000 km
# Diesel
# Automatyczna
# 2014
# Mercedes-Benz ML
# 2 987 cm3
# 58 KM
# 92 000PLN
# 245 000 km
# Diesel
# Automatyczna
# 2014
# Mercedes-Benz Klasa C 180 9G-TRONIC
# 1 595 cm3
# 56 KM
# 98 000PLN
# 94 000 km
# Benzyna
# Automatyczna
# 2018
# Mercedes-Benz Klasa E 220 d 4-Matic 9G-TRONIC
# 1 950 cm3
# 95 KM
# 139 900PLN
# 178 000 km
# Diesel
# Automatyczna
# 2017
# Mercedes-Benz Klasa S 580 4Matic L 9G-TRONIC
# 3 982 cm3
# 03 KM
# 570 000PLN
# 7 700 km
# Benzyna
# Automatyczna
# 2021
# Mercedes-Benz Klasa C 180 T BlueEFFICIENCY
# 1 796 cm3
# 56 KM
# 37 900PLN
# 136 002 km
# Benzyna
# Manualna
# 2010
# Mercedes-Benz Klasa C AMG 63
# 3 982 cm3
# 76 KM
# 199 900PLN
# 48 700 km
# Benzyna
# Automatyczna
# 2015
# Mercedes-Benz GL 400 4Matic 7G-TRONIC
# 2 996 cm3
# 33 KM
# 135 000PLN
# 85 000 km
# Benzyna
# Automatyczna
# 2015
# Mercedes-Benz EQS 580 4-Matic AMG Line
# 523 KM •
# 580AM
# 553 500PLN
# 20 500 km
# Elektryczny
# Automatyczna
# 2022
# Mercedes-Benz Klasa C 300 7G-TRONIC Avantgarde
# 1 991 cm3
# 45 KM
# 98 500PLN
# 134 500 km
# Benzyna
# Automatyczna
# 2016
# Mercedes-Benz Klasa C 180 CGI BlueEff Avantgarde
# 1 595 cm3
# 56 KM
# 71 000PLN
# 45 500 km
# Benzyna
# Manualna
# 2014
# Mercedes-Benz Klasa A 180 d 7G-DCT Edition 2020
# 1 461 cm3
# 16 KM
# 69 000PLN
# 107 000 km
# Diesel
# Automatyczna
# 2021
# Mercedes-Benz CLA 220 4-Matic AMG Line
# 1 991 cm3
# 84 KM
# 126 284PLN
# 118 000 km
# Benzyna
# Automatyczna
# 2017
# Mercedes-Benz Klasa B 250 (BlueEFFICIENCY) 7G-DCT
# 1 991 cm3
# 11 KM
# 44 900PLN
# 96 992 km
# Benzyna
# Automatyczna
# 2013
# Mercedes-Benz GLC 250 4-Matic
# 1 991 cm3
# 11 KM
# 157 900PLN
# 53 000 km
# Benzyna
# Automatyczna
# 2018
# Mercedes-Benz GLB 200 AMG Line 7G-DCT
# 1 332 cm3
# 63 KM
# 159 500PLN
# 96 000 km
# Benzyna
# Automatyczna
# 2020
# Mercedes-Benz SL 500
# 4 973 cm3
# 20 KM
# 95 000PLN
# 175 000 km
# Benzyna
# Automatyczna
# 1998
# Mercedes-Benz Klasa C 300 7G-TRONIC
# 1 991 cm3
# 45 KM
# 135 000PLN
# 87 052 km
# Benzyna
# Automatyczna
# 2016
# Mercedes-Benz ML 420 CDI 4-Matic
# 3 996 cm3
# 06 KM
# 45 400PLN
# 251 400 km
# Diesel
# Automatyczna
# 2007
# Mercedes-Benz Klasa E 200 Coupe 4-Matic 9G-TRONIC
# 1 991 cm3
# 97 KM
# 220 000PLN
# 82 000 km
# Benzyna
# Automatyczna
# 2020
# Mercedes-Benz GLB 250 8G-DCT AMG Line
# 1 991 cm3
# 24 KM
# 179 000PLN
# 24 835 km
# Benzyna
# Automatyczna
# 2021
# Mercedes-Benz Klasa S 450 Coupe 4-Matic 9G-TRONIC
# 2 996 cm3
# 67 KM
# 380 000PLN
# 50 000 km
# Benzyna
# Automatyczna
# 2020
# Mercedes-Benz Klasa A 160 d
# 1 461 cm3
# 0 KM
# 54 500PLN
# 101 300 km
# Diesel
# Manualna
# 2016
# Mercedes-Benz Klasa B
# 1 461 cm3
# 09 KM
# 65 000PLN
# 179 297 km
# Diesel
# Automatyczna
# 2016
# Mercedes-Benz Klasa E 200
# 1 991 cm3
# 97 KM
# 163 000PLN
# 40 650 km
# Benzyna
# Automatyczna
# 2020
# Mercedes-Benz Klasa A
# 1 498 cm3
# 5 KM
# 19 900PLN
# 160 000 km
# Benzyna
# Manualna
# 2010
# Mercedes-Benz GLC 220 d 4-Matic
# 2 143 cm3
# 70 KM
# 149 888PLN
# 111 500 km
# Diesel
# Automatyczna
# 2018
# Mercedes-Benz Klasa C
# 1 796 cm3
# 84 KM
# 49 700PLN
# 182 000 km
# Benzyna
# Automatyczna
# 2011
# Mercedes-Benz CLA 220 4-Matic
# 1 991 cm3
# 84 KM
# 129 500PLN
# 58 000 km
# Benzyna
# Automatyczna
# 2018
#
# 1 461 cm3
# 09 KM
# 95 900PLN
# 135 000 km
# Diesel
# Automatyczna
# 2017
# Mercedes-Benz Klasa C 200 T CDI DPF Automatik BlueEFFICIENCY Avantgarde
# 2 143 cm3
# 36 KM
# 31 500PLN
# 280 000 km
# Diesel
# Automatyczna
# 2011
# Mercedes-Benz Klasa A AMG 45 4-Matic
# 1 991 cm3
# 81 KM
# 149 900PLN
# 67 164 km
# Benzyna
# Automatyczna
# 2016
# Mercedes-Benz Klasa C 250 (BlueTEC) d 4-Matic 7G-TRONIC
# 2 143 cm3
# 04 KM
# 70 000PLN
# 192 000 km
# Diesel
# Automatyczna
# 2014
# Mercedes-Benz ML
# 2 987 cm3
# 58 KM
# 92 000PLN
# 245 000 km
# Diesel
# Automatyczna
# 2014
# Mercedes-Benz Klasa C 180 9G-TRONIC
# 1 595 cm3
# 56 KM
# 98 000PLN
# 94 000 km
# Benzyna
# Automatyczna
# 2018
# Mercedes-Benz Klasa E 220 d 4-Matic 9G-TRONIC
# 1 950 cm3
# 95 KM
# 139 900PLN
# 178 000 km
# Diesel
# Automatyczna
# 2017
# Mercedes-Benz Klasa S 580 4Matic L 9G-TRONIC
# 3 982 cm3
# 03 KM
# 570 000PLN
# 7 700 km
# Benzyna
# Automatyczna
# 2021
# Mercedes-Benz Klasa C 180 T BlueEFFICIENCY
# 1 796 cm3
# 56 KM
# 37 900PLN
# 136 002 km
# Benzyna
# Manualna
# 2010
# Mercedes-Benz Klasa C AMG 63
# 3 982 cm3
# 76 KM
# 199 900PLN
# 48 700 km
# Benzyna
# Automatyczna
# 2015
# Mercedes-Benz GL 400 4Matic 7G-TRONIC
# 2 996 cm3
# 33 KM
# 135 000PLN
# 85 000 km
# Benzyna
# Automatyczna
# 2015
# Mercedes-Benz EQS 580 4-Matic AMG Line
# 523 KM •
# 580AM
# 553 500PLN
# 20 500 km
# Elektryczny
# Automatyczna
# 2022
# Mercedes-Benz Klasa C 300 7G-TRONIC Avantgarde
# 1 991 cm3
# 45 KM
# 98 500PLN
# 134 500 km
# Benzyna
# Automatyczna
# 2016
# Mercedes-Benz Klasa C 180 CGI BlueEff Avantgarde
# 1 595 cm3
# 56 KM
# 71 000PLN
# 45 500 km
# Benzyna
# Manualna
# 2014
# Mercedes-Benz Klasa A 180 d 7G-DCT Edition 2020
# 1 461 cm3
# 16 KM
# 69 000PLN
# 107 000 km
# Diesel
# Automatyczna
# 2021
# Mercedes-Benz CLA 220 4-Matic AMG Line
# 1 991 cm3
# 84 KM
# 126 284PLN
# 118 000 km
# Benzyna
# Automatyczna
# 2017
# Mercedes-Benz Klasa B 250 (BlueEFFICIENCY) 7G-DCT
# 1 991 cm3
# 11 KM
# 44 900PLN
# 96 992 km
# Benzyna
# Automatyczna
# 2013
# Mercedes-Benz GLC 250 4-Matic
# 1 991 cm3
# 11 KM
# 157 900PLN
# 53 000 km
# Benzyna
# Automatyczna
# 2018
# Mercedes-Benz GLB 200 AMG Line 7G-DCT
# 1 332 cm3
# 63 KM
# 159 500PLN
# 96 000 km
# Benzyna
# Automatyczna
# 2020
# Mercedes-Benz SL 500
# 4 973 cm3
# 20 KM
# 95 000PLN
# 175 000 km
# Benzyna
# Automatyczna
# 1998
# Mercedes-Benz Klasa C 300 7G-TRONIC
# 1 991 cm3
# 45 KM
# 135 000PLN
# 87 052 km
# Benzyna
# Automatyczna
# 2016
# Mercedes-Benz ML 420 CDI 4-Matic
# 3 996 cm3
# 06 KM
# 45 400PLN
# 251 400 km
# Diesel
# Automatyczna
# 2007
# Mercedes-Benz Klasa E 200 Coupe 4-Matic 9G-TRONIC
# 1 991 cm3
# 97 KM
# 220 000PLN
# 82 000 km
# Benzyna
# Automatyczna
# 2020
# Mercedes-Benz GLB 250 8G-DCT AMG Line
# 1 991 cm3
# 24 KM
# 179 000PLN
# 24 835 km
# Benzyna
# Automatyczna
# 2021
# Mercedes-Benz Klasa S 450 Coupe 4-Matic 9G-TRONIC
# 2 996 cm3
# 67 KM
# 380 000PLN
# 50 000 km
# Benzyna
# Automatyczna
# 2020
# Mercedes-Benz Klasa A 160 d
# 1 461 cm3
# 0 KM
# 54 500PLN
# 101 300 km
# Diesel
# Manualna
# 2016
# Mercedes-Benz Klasa B
# 1 461 cm3
# 09 KM
# 65 000PLN
# 179 297 km
# Diesel
# Automatyczna
# 2016
# Mercedes-Benz Klasa E 200
# 1 991 cm3
# 97 KM
# 163 000PLN
# 40 650 km
# Benzyna
# Automatyczna
# 2020
# Mercedes-Benz Klasa A
# 1 498 cm3
# 5 KM
# 19 900PLN
# 160 000 km
# Benzyna
# Manualna
# 2010
# Mercedes-Benz GLC 220 d 4-Matic
# 2 143 cm3
# 70 KM
# 149 888PLN
# 111 500 km
# Diesel
# Automatyczna
# 2018
# Mercedes-Benz Klasa C
# 1 796 cm3
# 84 KM
# 49 700PLN
# 182 000 km
# Benzyna
# Automatyczna
# 2011
# Mercedes-Benz CLA 220 4-Matic
# 1 991 cm3
# 84 KM
# 129 500PLN
# 58 000 km
# Benzyna
# Automatyczna
# 2018
#
# 1 461 cm3
# 09 KM
# 95 900PLN
# 135 000 km
# Diesel
# Automatyczna
# 2017
# Mercedes-Benz Klasa C 200 T CDI DPF Automatik BlueEFFICIENCY Avantgarde
# 2 143 cm3
# 36 KM
# 31 500PLN
# 280 000 km
# Diesel
# Automatyczna
# 2011
# Mercedes-Benz Klasa A AMG 45 4-Matic
# 1 991 cm3
# 81 KM
# 149 900PLN
# 67 164 km
# Benzyna
# Automatyczna
# 2016
# Mercedes-Benz Klasa C 250 (BlueTEC) d 4-Matic 7G-TRONIC
# 2 143 cm3
# 04 KM
# 70 000PLN
# 192 000 km
# Diesel
# Automatyczna
# 2014
# Mercedes-Benz ML
# 2 987 cm3
# 58 KM
# 92 000PLN
# 245 000 km
# Diesel
# Automatyczna
# 2014
# Mercedes-Benz Klasa C 180 9G-TRONIC
# 1 595 cm3
# 56 KM
# 98 000PLN
# 94 000 km
# Benzyna
# Automatyczna
# 2018
# Mercedes-Benz Klasa E 220 d 4-Matic 9G-TRONIC
# 1 950 cm3
# 95 KM
# 139 900PLN
# 178 000 km
# Diesel
# Automatyczna
# 2017
# Mercedes-Benz Klasa S 580 4Matic L 9G-TRONIC
# 3 982 cm3
# 03 KM
# 570 000PLN
# 7 700 km
# Benzyna
# Automatyczna
# 2021
# Mercedes-Benz Klasa C 180 T BlueEFFICIENCY
# 1 796 cm3
# 56 KM
# 37 900PLN
# 136 002 km
# Benzyna
# Manualna
# 2010
# Mercedes-Benz Klasa C AMG 63
# 3 982 cm3
# 76 KM
# 199 900PLN
# 48 700 km
# Benzyna
# Automatyczna
# 2015
# Mercedes-Benz GL 400 4Matic 7G-TRONIC
# 2 996 cm3
# 33 KM
# 135 000PLN
# 85 000 km
# Benzyna
# Automatyczna
# 2015
# Mercedes-Benz EQS 580 4-Matic AMG Line
# 523 KM •
# 580AM
# 553 500PLN
# 20 500 km
# Elektryczny
# Automatyczna
# 2022
# Mercedes-Benz Klasa C 300 7G-TRONIC Avantgarde
# 1 991 cm3
# 45 KM
# 98 500PLN
# 134 500 km
# Benzyna
# Automatyczna
# 2016
# Mercedes-Benz Klasa C 180 CGI BlueEff Avantgarde
# 1 595 cm3
# 56 KM
# 71 000PLN
# 45 500 km
# Benzyna
# Manualna
# 2014
# Mercedes-Benz Klasa A 180 d 7G-DCT Edition 2020
# 1 461 cm3
# 16 KM
# 69 000PLN
# 107 000 km
# Diesel
# Automatyczna
# 2021
# Mercedes-Benz CLA 220 4-Matic AMG Line
# 1 991 cm3
# 84 KM
# 126 284PLN
# 118 000 km
# Benzyna
# Automatyczna
# 2017
# Mercedes-Benz Klasa B 250 (BlueEFFICIENCY) 7G-DCT
# 1 991 cm3
# 11 KM
# 44 900PLN
# 96 992 km
# Benzyna
# Automatyczna
# 2013
# Mercedes-Benz GLC 250 4-Matic
# 1 991 cm3
# 11 KM
# 157 900PLN
# 53 000 km
# Benzyna
# Automatyczna
# 2018
# Mercedes-Benz GLB 200 AMG Line 7G-DCT
# 1 332 cm3
# 63 KM
# 159 500PLN
# 96 000 km
# Benzyna
# Automatyczna
# 2020
# Mercedes-Benz SL 500
# 4 973 cm3
# 20 KM
# 95 000PLN
# 175 000 km
# Benzyna
# Automatyczna
# 1998
# Mercedes-Benz Klasa C 300 7G-TRONIC
# 1 991 cm3
# 45 KM
# 135 000PLN
# 87 052 km
# Benzyna
# Automatyczna
# 2016
# Mercedes-Benz ML 420 CDI 4-Matic
# 3 996 cm3
# 06 KM
# 45 400PLN
# 251 400 km
# Diesel
# Automatyczna
# 2007
# Mercedes-Benz Klasa E 200 Coupe 4-Matic 9G-TRONIC
# 1 991 cm3
# 97 KM
# 220 000PLN
# 82 000 km
# Benzyna
# Automatyczna
# 2020
# Mercedes-Benz GLB 250 8G-DCT AMG Line
# 1 991 cm3
# 24 KM
# 179 000PLN
# 24 835 km
# Benzyna
# Automatyczna
# 2021
# Mercedes-Benz Klasa S 450 Coupe 4-Matic 9G-TRONIC
# 2 996 cm3
# 67 KM
# 380 000PLN
# 50 000 km
# Benzyna
# Automatyczna
# 2020
# Mercedes-Benz Klasa A 160 d
# 1 461 cm3
# 0 KM
# 54 500PLN
# 101 300 km
# Diesel
# Manualna
# 2016
# Mercedes-Benz Klasa B
# 1 461 cm3
# 09 KM
# 65 000PLN
# 179 297 km
# Diesel
# Automatyczna
# 2016
# Mercedes-Benz Klasa E 200
# 1 991 cm3
# 97 KM
# 163 000PLN
# 40 650 km
# Benzyna
# Automatyczna
# 2020
# Mercedes-Benz Klasa A
# 1 498 cm3
# 5 KM
# 19 900PLN
# 160 000 km
# Benzyna
# Manualna
# 2010
# Mercedes-Benz GLC 220 d 4-Matic
# 2 143 cm3
# 70 KM
# 149 888PLN
# 111 500 km
# Diesel
# Automatyczna
# 2018
# Mercedes-Benz Klasa C
# 1 796 cm3
# 84 KM
# 49 700PLN
# 182 000 km
# Benzyna
# Automatyczna
# 2011
# Mercedes-Benz CLA 220 4-Matic
# 1 991 cm3
# 84 KM
# 129 500PLN
# 58 000 km
# Benzyna
# Automatyczna
# 2018
#
# 1 461 cm3
# 09 KM
# 95 900PLN
# 135 000 km
# Diesel
# Automatyczna
# 2017
# Mercedes-Benz Klasa C 200 T CDI DPF Automatik BlueEFFICIENCY Avantgarde
# 2 143 cm3
# 36 KM
# 31 500PLN
# 280 000 km
# Diesel
# Automatyczna
# 2011
# Mercedes-Benz Klasa A AMG 45 4-Matic
# 1 991 cm3
# 81 KM
# 149 900PLN
# 67 164 km
# Benzyna
# Automatyczna
# 2016
# Mercedes-Benz Klasa C 250 (BlueTEC) d 4-Matic 7G-TRONIC
# 2 143 cm3
# 04 KM
# 70 000PLN
# 192 000 km
# Diesel
# Automatyczna
# 2014
# Mercedes-Benz ML
# 2 987 cm3
# 58 KM
# 92 000PLN
# 245 000 km
# Diesel
# Automatyczna
# 2014
# Mercedes-Benz Klasa C 180 9G-TRONIC
# 1 595 cm3
# 56 KM
# 98 000PLN
# 94 000 km
# Benzyna
# Automatyczna
# 2018
# Mercedes-Benz Klasa E 220 d 4-Matic 9G-TRONIC
# 1 950 cm3
# 95 KM
# 139 900PLN
# 178 000 km
# Diesel
# Automatyczna
# 2017
# Mercedes-Benz Klasa S 580 4Matic L 9G-TRONIC
# 3 982 cm3
# 03 KM
# 570 000PLN
# 7 700 km
# Benzyna
# Automatyczna
# 2021
# Mercedes-Benz Klasa C 180 T BlueEFFICIENCY
# 1 796 cm3
# 56 KM
# 37 900PLN
# 136 002 km
# Benzyna
# Manualna
# 2010
# Mercedes-Benz Klasa C AMG 63
# 3 982 cm3
# 76 KM
# 199 900PLN
# 48 700 km
# Benzyna
# Automatyczna
# 2015
# Mercedes-Benz GL 400 4Matic 7G-TRONIC
# 2 996 cm3
# 33 KM
# 135 000PLN
# 85 000 km
# Benzyna
# Automatyczna
# 2015
# Mercedes-Benz EQS 580 4-Matic AMG Line
# 523 KM •
# 580AM
# 553 500PLN
# 20 500 km
# Elektryczny
# Automatyczna
# 2022
# Mercedes-Benz Klasa C 300 7G-TRONIC Avantgarde
# 1 991 cm3
# 45 KM
# 98 500PLN
# 134 500 km
# Benzyna
# Automatyczna
# 2016
# Mercedes-Benz Klasa C 180 CGI BlueEff Avantgarde
# 1 595 cm3
# 56 KM
# 71 000PLN
# 45 500 km
# Benzyna
# Manualna
# 2014
# Mercedes-Benz Klasa A 180 d 7G-DCT Edition 2020
# 1 461 cm3
# 16 KM
# 69 000PLN
# 107 000 km
# Diesel
# Automatyczna
# 2021
# Mercedes-Benz CLA 220 4-Matic AMG Line
# 1 991 cm3
# 84 KM
# 126 284PLN
# 118 000 km
# Benzyna
# Automatyczna
# 2017
# Mercedes-Benz Klasa B 250 (BlueEFFICIENCY) 7G-DCT
# 1 991 cm3
# 11 KM
# 44 900PLN
# 96 992 km
# Benzyna
# Automatyczna
# 2013
# Mercedes-Benz GLC 250 4-Matic
# 1 991 cm3
# 11 KM
# 157 900PLN
# 53 000 km
# Benzyna
# Automatyczna
# 2018
# Mercedes-Benz GLB 200 AMG Line 7G-DCT
# 1 332 cm3
# 63 KM
# 159 500PLN
# 96 000 km
# Benzyna
# Automatyczna
# 2020
# Mercedes-Benz SL 500
# 4 973 cm3
# 20 KM
# 95 000PLN
# 175 000 km
# Benzyna
# Automatyczna
# 1998
# Mercedes-Benz Klasa C 300 7G-TRONIC
# 1 991 cm3
# 45 KM
# 135 000PLN
# 87 052 km
# Benzyna
# Automatyczna
# 2016
# Mercedes-Benz ML 420 CDI 4-Matic
# 3 996 cm3
# 06 KM
# 45 400PLN
# 251 400 km
# Diesel
# Automatyczna
# 2007
# Mercedes-Benz Klasa E 200 Coupe 4-Matic 9G-TRONIC
# 1 991 cm3
# 97 KM
# 220 000PLN
# 82 000 km
# Benzyna
# Automatyczna
# 2020
# Mercedes-Benz GLB 250 8G-DCT AMG Line
# 1 991 cm3
# 24 KM
# 179 000PLN
# 24 835 km
# Benzyna
# Automatyczna
# 2021
# Mercedes-Benz Klasa S 450 Coupe 4-Matic 9G-TRONIC
# 2 996 cm3
# 67 KM
# 380 000PLN
# 50 000 km
# Benzyna
# Automatyczna
# 2020
# Mercedes-Benz Klasa A 160 d
# 1 461 cm3
# 0 KM
# 54 500PLN
# 101 300 km
# Diesel
# Manualna
# 2016
# Mercedes-Benz Klasa B
# 1 461 cm3
# 09 KM
# 65 000PLN
# 179 297 km
# Diesel
# Automatyczna
# 2016
# Mercedes-Benz Klasa E 200
# 1 991 cm3
# 97 KM
# 163 000PLN
# 40 650 km
# Benzyna
# Automatyczna
# 2020
# Mercedes-Benz Klasa A
# 1 498 cm3
# 5 KM
# 19 900PLN
# 160 000 km
# Benzyna
# Manualna
# 2010
# Mercedes-Benz GLC 220 d 4-Matic
# 2 143 cm3
# 70 KM
# 149 888PLN
# 111 500 km
# Diesel
# Automatyczna
# 2018
# Mercedes-Benz Klasa C
# 1 796 cm3
# 84 KM
# 49 700PLN
# 182 000 km
# Benzyna
# Automatyczna
# 2011
# Mercedes-Benz CLA 220 4-Matic
# 1 991 cm3
# 84 KM
# 129 500PLN
# 58 000 km
# Benzyna
# Automatyczna
# 2018
#
# 1 461 cm3
# 09 KM
# 95 900PLN
# 135 000 km
# Diesel
# Automatyczna
# 2017
# Mercedes-Benz Klasa C 200 T CDI DPF Automatik BlueEFFICIENCY Avantgarde
# 2 143 cm3
# 36 KM
# 31 500PLN
# 280 000 km
# Diesel
# Automatyczna
# 2011
# Mercedes-Benz Klasa A AMG 45 4-Matic
# 1 991 cm3
# 81 KM
# 149 900PLN
# 67 164 km
# Benzyna
# Automatyczna
# 2016
# Mercedes-Benz Klasa C 250 (BlueTEC) d 4-Matic 7G-TRONIC
# 2 143 cm3
# 04 KM
# 70 000PLN
# 192 000 km
# Diesel
# Automatyczna
# 2014
# Mercedes-Benz ML
# 2 987 cm3
# 58 KM
# 92 000PLN
# 245 000 km
# Diesel
# Automatyczna
# 2014
# Mercedes-Benz Klasa C 180 9G-TRONIC
# 1 595 cm3
# 56 KM
# 98 000PLN
# 94 000 km
# Benzyna
# Automatyczna
# 2018
# Mercedes-Benz Klasa E 220 d 4-Matic 9G-TRONIC
# 1 950 cm3
# 95 KM
# 139 900PLN
# 178 000 km
# Diesel
# Automatyczna
# 2017
# Mercedes-Benz Klasa S 580 4Matic L 9G-TRONIC
# 3 982 cm3
# 03 KM
# 570 000PLN
# 7 700 km
# Benzyna
# Automatyczna
# 2021
# Mercedes-Benz Klasa C 180 T BlueEFFICIENCY
# 1 796 cm3
# 56 KM
# 37 900PLN
# 136 002 km
# Benzyna
# Manualna
# 2010
# Mercedes-Benz Klasa C AMG 63
# 3 982 cm3
# 76 KM
# 199 900PLN
# 48 700 km
# Benzyna
# Automatyczna
# 2015
# Mercedes-Benz GL 400 4Matic 7G-TRONIC
# 2 996 cm3
# 33 KM
# 135 000PLN
# 85 000 km
# Benzyna
# Automatyczna
# 2015
# Mercedes-Benz EQS 580 4-Matic AMG Line
# 523 KM •
# 580AM
# 553 500PLN
# 20 500 km
# Elektryczny
# Automatyczna
# 2022
# Mercedes-Benz Klasa C 300 7G-TRONIC Avantgarde
# 1 991 cm3
# 45 KM
# 98 500PLN
# 134 500 km
# Benzyna
# Automatyczna
# 2016
# Mercedes-Benz Klasa C 180 CGI BlueEff Avantgarde
# 1 595 cm3
# 56 KM
# 71 000PLN
# 45 500 km
# Benzyna
# Manualna
# 2014
# Mercedes-Benz Klasa A 180 d 7G-DCT Edition 2020
# 1 461 cm3
# 16 KM
# 69 000PLN
# 107 000 km
# Diesel
# Automatyczna
# 2021
# Mercedes-Benz CLA 220 4-Matic AMG Line
# 1 991 cm3
# 84 KM
# 126 284PLN
# 118 000 km
# Benzyna
# Automatyczna
# 2017
# Mercedes-Benz Klasa B 250 (BlueEFFICIENCY) 7G-DCT
# 1 991 cm3
# 11 KM
# 44 900PLN
# 96 992 km
# Benzyna
# Automatyczna
# 2013
# Mercedes-Benz GLC 250 4-Matic
# 1 991 cm3
# 11 KM
# 157 900PLN
# 53 000 km
# Benzyna
# Automatyczna
# 2018
# Mercedes-Benz GLB 200 AMG Line 7G-DCT
# 1 332 cm3
# 63 KM
# 159 500PLN
# 96 000 km
# Benzyna
# Automatyczna
# 2020
# Mercedes-Benz SL 500
# 4 973 cm3
# 20 KM
# 95 000PLN
# 175 000 km
# Benzyna
# Automatyczna
# 1998
# Mercedes-Benz Klasa C 300 7G-TRONIC
# 1 991 cm3
# 45 KM
# 135 000PLN
# 87 052 km
# Benzyna
# Automatyczna
# 2016
# Mercedes-Benz ML 420 CDI 4-Matic
# 3 996 cm3
# 06 KM
# 45 400PLN
# 251 400 km
# Diesel
# Automatyczna
# 2007
# Mercedes-Benz Klasa E 200 Coupe 4-Matic 9G-TRONIC
# 1 991 cm3
# 97 KM
# 220 000PLN
# 82 000 km
# Benzyna
# Automatyczna
# 2020
# Mercedes-Benz GLB 250 8G-DCT AMG Line
# 1 991 cm3
# 24 KM
# 179 000PLN
# 24 835 km
# Benzyna
# Automatyczna
# 2021
# Mercedes-Benz Klasa S 450 Coupe 4-Matic 9G-TRONIC
# 2 996 cm3
# 67 KM
# 380 000PLN
# 50 000 km
# Benzyna
# Automatyczna
# 2020
# Mercedes-Benz Klasa A 160 d
# 1 461 cm3
# 0 KM
# 54 500PLN
# 101 300 km
# Diesel
# Manualna
# 2016
# Mercedes-Benz Klasa B
# 1 461 cm3
# 09 KM
# 65 000PLN
# 179 297 km
# Diesel
# Automatyczna
# 2016
# Mercedes-Benz Klasa E 200
# 1 991 cm3
# 97 KM
# 163 000PLN
# 40 650 km
# Benzyna
# Automatyczna
# 2020
# Mercedes-Benz Klasa A
# 1 498 cm3
# 5 KM
# 19 900PLN
# 160 000 km
# Benzyna
# Manualna
# 2010
# Mercedes-Benz GLC 220 d 4-Matic
# 2 143 cm3
# 70 KM
# 149 888PLN
# 111 500 km
# Diesel
# Automatyczna
# 2018
# Mercedes-Benz Klasa C
# 1 796 cm3
# 84 KM
# 49 700PLN
# 182 000 km
# Benzyna
# Automatyczna
# 2011
# Mercedes-Benz CLA 220 4-Matic
# 1 991 cm3
# 84 KM
# 129 500PLN
# 58 000 km
# Benzyna
# Automatyczna
# 2018
#
# 1 461 cm3
# 09 KM
# 95 900PLN
# 135 000 km
# Diesel
# Automatyczna
# 2017
# Mercedes-Benz Klasa C 200 T CDI DPF Automatik BlueEFFICIENCY Avantgarde
# 2 143 cm3
# 36 KM
# 31 500PLN
# 280 000 km
# Diesel
# Automatyczna
# 2011
# Mercedes-Benz Klasa A AMG 45 4-Matic
# 1 991 cm3
# 81 KM
# 149 900PLN
# 67 164 km
# Benzyna
# Automatyczna
# 2016
# Mercedes-Benz Klasa C 250 (BlueTEC) d 4-Matic 7G-TRONIC
# 2 143 cm3
# 04 KM
# 70 000PLN
# 192 000 km
# Diesel
# Automatyczna
# 2014
# Mercedes-Benz ML
# 2 987 cm3
# 58 KM
# 92 000PLN
# 245 000 km
# Diesel
# Automatyczna
# 2014
# Mercedes-Benz Klasa C 180 9G-TRONIC
# 1 595 cm3
# 56 KM
# 98 000PLN
# 94 000 km
# Benzyna
# Automatyczna
# 2018
# Mercedes-Benz Klasa E 220 d 4-Matic 9G-TRONIC
# 1 950 cm3
# 95 KM
# 139 900PLN
# 178 000 km
# Diesel
# Automatyczna
# 2017
# Mercedes-Benz Klasa S 580 4Matic L 9G-TRONIC
# 3 982 cm3
# 03 KM
# 570 000PLN
# 7 700 km
# Benzyna
# Automatyczna
# 2021
# Mercedes-Benz Klasa C 180 T BlueEFFICIENCY
# 1 796 cm3
# 56 KM
# 37 900PLN
# 136 002 km
# Benzyna
# Manualna
# 2010
# Mercedes-Benz Klasa C AMG 63
# 3 982 cm3
# 76 KM
# 199 900PLN
# 48 700 km
# Benzyna
# Automatyczna
# 2015
# Mercedes-Benz GL 400 4Matic 7G-TRONIC
# 2 996 cm3
# 33 KM
# 135 000PLN
# 85 000 km
# Benzyna
# Automatyczna
# 2015
# Mercedes-Benz EQS 580 4-Matic AMG Line
# 523 KM •
# 580AM
# 553 500PLN
# 20 500 km
# Elektryczny
# Automatyczna
# 2022
# Mercedes-Benz Klasa C 300 7G-TRONIC Avantgarde
# 1 991 cm3
# 45 KM
# 98 500PLN
# 134 500 km
# Benzyna
# Automatyczna
# 2016
# Mercedes-Benz Klasa C 180 CGI BlueEff Avantgarde
# 1 595 cm3
# 56 KM
# 71 000PLN
# 45 500 km
# Benzyna
# Manualna
# 2014
# Mercedes-Benz Klasa A 180 d 7G-DCT Edition 2020
# 1 461 cm3
# 16 KM
# 69 000PLN
# 107 000 km
# Diesel
# Automatyczna
# 2021
# Mercedes-Benz CLA 220 4-Matic AMG Line
# 1 991 cm3
# 84 KM
# 126 284PLN
# 118 000 km
# Benzyna
# Automatyczna
# 2017
# Mercedes-Benz Klasa B 250 (BlueEFFICIENCY) 7G-DCT
# 1 991 cm3
# 11 KM
# 44 900PLN
# 96 992 km
# Benzyna
# Automatyczna
# 2013
# Mercedes-Benz GLC 250 4-Matic
# 1 991 cm3
# 11 KM
# 157 900PLN
# 53 000 km
# Benzyna
# Automatyczna
# 2018
# Mercedes-Benz GLB 200 AMG Line 7G-DCT
# 1 332 cm3
# 63 KM
# 159 500PLN
# 96 000 km
# Benzyna
# Automatyczna
# 2020
# Mercedes-Benz SL 500
# 4 973 cm3
# 20 KM
# 95 000PLN
# 175 000 km
# Benzyna
# Automatyczna
# 1998
# Mercedes-Benz Klasa C 300 7G-TRONIC
# 1 991 cm3
# 45 KM
# 135 000PLN
# 87 052 km
# Benzyna
# Automatyczna
# 2016
# Mercedes-Benz ML 420 CDI 4-Matic
# 3 996 cm3
# 06 KM
# 45 400PLN
# 251 400 km
# Diesel
# Automatyczna
# 2007
# Mercedes-Benz Klasa E 200 Coupe 4-Matic 9G-TRONIC
# 1 991 cm3
# 97 KM
# 220 000PLN
# 82 000 km
# Benzyna
# Automatyczna
# 2020
# Mercedes-Benz GLB 250 8G-DCT AMG Line
# 1 991 cm3
# 24 KM
# 179 000PLN
# 24 835 km
# Benzyna
# Automatyczna
# 2021
# Mercedes-Benz Klasa S 450 Coupe 4-Matic 9G-TRONIC
# 2 996 cm3
# 67 KM
# 380 000PLN
# 50 000 km
# Benzyna
# Automatyczna
# 2020
# Mercedes-Benz Klasa A 160 d
# 1 461 cm3
# 0 KM
# 54 500PLN
# 101 300 km
# Diesel
# Manualna
# 2016
# Mercedes-Benz Klasa B
# 1 461 cm3
# 09 KM
# 65 000PLN
# 179 297 km
# Diesel
# Automatyczna
# 2016
# Mercedes-Benz Klasa E 200
# 1 991 cm3
# 97 KM
# 163 000PLN
# 40 650 km
# Benzyna
# Automatyczna
# 2020
# Mercedes-Benz Klasa A
# 1 498 cm3
# 5 KM
# 19 900PLN
# 160 000 km
# Benzyna
# Manualna
# 2010
# Mercedes-Benz GLC 220 d 4-Matic
# 2 143 cm3
# 70 KM
# 149 888PLN
# 111 500 km
# Diesel
# Automatyczna
# 2018
# Mercedes-Benz Klasa C
# 1 796 cm3
# 84 KM
# 49 700PLN
# 182 000 km
# Benzyna
# Automatyczna
# 2011
# Mercedes-Benz CLA 220 4-Matic
# 1 991 cm3
# 84 KM
# 129 500PLN
# 58 000 km
# Benzyna
# Automatyczna
# 2018
#
# 1 461 cm3
# 09 KM
# 95 900PLN
# 135 000 km
# Diesel
# Automatyczna
# 2017
# Mercedes-Benz Klasa C 200 T CDI DPF Automatik BlueEFFICIENCY Avantgarde
# 2 143 cm3
# 36 KM
# 31 500PLN
# 280 000 km
# Diesel
# Automatyczna
# 2011
# Mercedes-Benz Klasa A AMG 45 4-Matic
# 1 991 cm3
# 81 KM
# 149 900PLN
# 67 164 km
# Benzyna
# Automatyczna
# 2016
# Mercedes-Benz Klasa C 250 (BlueTEC) d 4-Matic 7G-TRONIC
# 2 143 cm3
# 04 KM
# 70 000PLN
# 192 000 km
# Diesel
# Automatyczna
# 2014
# Mercedes-Benz ML
# 2 987 cm3
# 58 KM
# 92 000PLN
# 245 000 km
# Diesel
# Automatyczna
# 2014
# Mercedes-Benz Klasa C 180 9G-TRONIC
# 1 595 cm3
# 56 KM
# 98 000PLN
# 94 000 km
# Benzyna
# Automatyczna
# 2018
# Mercedes-Benz Klasa E 220 d 4-Matic 9G-TRONIC
# 1 950 cm3
# 95 KM
# 139 900PLN
# 178 000 km
# Diesel
# Automatyczna
# 2017
# Mercedes-Benz Klasa S 580 4Matic L 9G-TRONIC
# 3 982 cm3
# 03 KM
# 570 000PLN
# 7 700 km
# Benzyna
# Automatyczna
# 2021
# Mercedes-Benz Klasa C 180 T BlueEFFICIENCY
# 1 796 cm3
# 56 KM
# 37 900PLN
# 136 002 km
# Benzyna
# Manualna
# 2010
# Mercedes-Benz Klasa C AMG 63
# 3 982 cm3
# 76 KM
# 199 900PLN
# 48 700 km
# Benzyna
# Automatyczna
# 2015
# Mercedes-Benz GL 400 4Matic 7G-TRONIC
# 2 996 cm3
# 33 KM
# 135 000PLN
# 85 000 km
# Benzyna
# Automatyczna
# 2015
# Mercedes-Benz EQS 580 4-Matic AMG Line
# 523 KM •
# 580AM
# 553 500PLN
# 20 500 km
# Elektryczny
# Automatyczna
# 2022
# Mercedes-Benz Klasa C 300 7G-TRONIC Avantgarde
# 1 991 cm3
# 45 KM
# 98 500PLN
# 134 500 km
# Benzyna
# Automatyczna
# 2016
# Mercedes-Benz Klasa C 180 CGI BlueEff Avantgarde
# 1 595 cm3
# 56 KM
# 71 000PLN
# 45 500 km
# Benzyna
# Manualna
# 2014
# Mercedes-Benz Klasa A 180 d 7G-DCT Edition 2020
# 1 461 cm3
# 16 KM
# 69 000PLN
# 107 000 km
# Diesel
# Automatyczna
# 2021
# Mercedes-Benz CLA 220 4-Matic AMG Line
# 1 991 cm3
# 84 KM
# 126 284PLN
# 118 000 km
# Benzyna
# Automatyczna
# 2017
# Mercedes-Benz Klasa B 250 (BlueEFFICIENCY) 7G-DCT
# 1 991 cm3
# 11 KM
# 44 900PLN
# 96 992 km
# Benzyna
# Automatyczna
# 2013
# Mercedes-Benz GLC 250 4-Matic
# 1 991 cm3
# 11 KM
# 157 900PLN
# 53 000 km
# Benzyna
# Automatyczna
# 2018
# Mercedes-Benz GLB 200 AMG Line 7G-DCT
# 1 332 cm3
# 63 KM
# 159 500PLN
# 96 000 km
# Benzyna
# Automatyczna
# 2020
# Mercedes-Benz SL 500
# 4 973 cm3
# 20 KM
# 95 000PLN
# 175 000 km
# Benzyna
# Automatyczna
# 1998
# Mercedes-Benz Klasa C 300 7G-TRONIC
# 1 991 cm3
# 45 KM
# 135 000PLN
# 87 052 km
# Benzyna
# Automatyczna
# 2016
# Mercedes-Benz ML 420 CDI 4-Matic
# 3 996 cm3
# 06 KM
# 45 400PLN
# 251 400 km
# Diesel
# Automatyczna
# 2007
# Mercedes-Benz Klasa E 200 Coupe 4-Matic 9G-TRONIC
# 1 991 cm3
# 97 KM
# 220 000PLN
# 82 000 km
# Benzyna
# Automatyczna
# 2020
# Mercedes-Benz GLB 250 8G-DCT AMG Line
# 1 991 cm3
# 24 KM
# 179 000PLN
# 24 835 km
# Benzyna
# Automatyczna
# 2021
# Mercedes-Benz Klasa S 450 Coupe 4-Matic 9G-TRONIC
# 2 996 cm3
# 67 KM
# 380 000PLN
# 50 000 km
# Benzyna
# Automatyczna
# 2020
# Mercedes-Benz Klasa A 160 d
# 1 461 cm3
# 0 KM
# 54 500PLN
# 101 300 km
# Diesel
# Manualna
# 2016
# Mercedes-Benz Klasa B
# 1 461 cm3
# 09 KM
# 65 000PLN
# 179 297 km
# Diesel
# Automatyczna
# 2016
# Mercedes-Benz Klasa E 200
# 1 991 cm3
# 97 KM
# 163 000PLN
# 40 650 km
# Benzyna
# Automatyczna
# 2020
# Mercedes-Benz Klasa A
# 1 498 cm3
# 5 KM
# 19 900PLN
# 160 000 km
# Benzyna
# Manualna
# 2010
# Mercedes-Benz GLC 220 d 4-Matic
# 2 143 cm3
# 70 KM
# 149 888PLN
# 111 500 km
# Diesel
# Automatyczna
# 2018
# Mercedes-Benz Klasa C
# 1 796 cm3
# 84 KM
# 49 700PLN
# 182 000 km
# Benzyna
# Automatyczna
# 2011
# Mercedes-Benz CLA 220 4-Matic
# 1 991 cm3
# 84 KM
# 129 500PLN
# 58 000 km
# Benzyna
# Automatyczna
# 2018
#
# 1 461 cm3
# 09 KM
# 95 900PLN
# 135 000 km
# Diesel
# Automatyczna
# 2017
# Mercedes-Benz Klasa C 200 T CDI DPF Automatik BlueEFFICIENCY Avantgarde
# 2 143 cm3
# 36 KM
# 31 500PLN
# 280 000 km
# Diesel
# Automatyczna
# 2011
# Mercedes-Benz Klasa A AMG 45 4-Matic
# 1 991 cm3
# 81 KM
# 149 900PLN
# 67 164 km
# Benzyna
# Automatyczna
# 2016
# Mercedes-Benz Klasa C 250 (BlueTEC) d 4-Matic 7G-TRONIC
# 2 143 cm3
# 04 KM
# 70 000PLN
# 192 000 km
# Diesel
# Automatyczna
# 2014
# Mercedes-Benz ML
# 2 987 cm3
# 58 KM
# 92 000PLN
# 245 000 km
# Diesel
# Automatyczna
# 2014
# Mercedes-Benz Klasa C 180 9G-TRONIC
# 1 595 cm3
# 56 KM
# 98 000PLN
# 94 000 km
# Benzyna
# Automatyczna
# 2018
# Mercedes-Benz Klasa E 220 d 4-Matic 9G-TRONIC
# 1 950 cm3
# 95 KM
# 139 900PLN
# 178 000 km
# Diesel
# Automatyczna
# 2017
# Mercedes-Benz Klasa S 580 4Matic L 9G-TRONIC
# 3 982 cm3
# 03 KM
# 570 000PLN
# 7 700 km
# Benzyna
# Automatyczna
# 2021
# Mercedes-Benz Klasa C 180 T BlueEFFICIENCY
# 1 796 cm3
# 56 KM
# 37 900PLN
# 136 002 km
# Benzyna
# Manualna
# 2010
# Mercedes-Benz Klasa C AMG 63
# 3 982 cm3
# 76 KM
# 199 900PLN
# 48 700 km
# Benzyna
# Automatyczna
# 2015
